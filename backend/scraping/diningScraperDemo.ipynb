# %%
import bs4 as bs
import requests
import re
import json

# %%
def getRestSiteMap():
    menus = {}
    url = "https://my.uhds.oregonstate.edu/api/dining/weeklymenu/1"
    response = requests.get(url)
    soup = bs.BeautifulSoup(response.text, 'html.parser')
    locations = soup.find('select', id='locations')
    options = locations.find_all('option')
    for option in options:
        location = option.text.strip()
        location = location.replace('é', 'e')
        value = option['value']
        menus[location] = value

    # rename the key to a different name
    menus['The MainSqueeze'] = menus.pop('The Main Squeeze')
    menus["Bing's at Weatherford"] = menus.pop("Bing's Cafe")
    return menus
rest_site_map = getRestSiteMap()
display(rest_site_map)
# Out:
# {"Ava's Cafe": '7',
#  'Bay Leaf': '14',
#  'Bites': '22',
#  "Calabaloo's": '16',
#  'Cascadia Cafe': '3',
#  'Cascadia Deli': '4',
#  'Cascadia Market': '5',
#  'Clubhouse Deli': '9',
#  'Coffee Corral': '8',
#  "Cooper's Creek": '10',
#  'Dixon Cafe': '2',
#  'e.Cafe': '6',
#  'East Side Eats': '17',
#  'EBGBs': '11',
#  'Five Four One': '18',
#  'Global Fare': '27',
#  'Grill': '30',
#  'Java II': '32',
#  'JavaStop': '23',
#  'La Calle': '19',
#  'Nori': '28',
#  'North Porch Cafe': '24',
#  'Off The Quad': '25',
#  'Raintree Coffee Co.': '20',
#  'Ring of Fire': '12',
#  'Serrano Grill': '13',
#  'Southside Station Deli': '26',
#  'Southside Station Pizzeria': '29',
#  'The Dam': '31',
#  "Trader Bing's Cafe": '1',
#  'West Side Grill': '15',
#  'The MainSqueeze': '21',
#  "Bing's at Weatherford": '33'}

# %%
def getRestAddress(url):
    response = requests.get(url)
    soup = bs.BeautifulSoup(response.text, 'html.parser')
    # find p tag with text location
    location = soup.find('p', string=re.compile('Location')).find_next_sibling('p').text.strip().replace('\n', ', ').replace('\t', '')
    return location

display(getRestAddress("https://uhds.oregonstate.edu/restaurants/bings-cafe"))
# Out:
# 'Weatherford Hall, 300 SW 26th St, Corvallis OR 97331'

# %%
def getRestName(url):
    source = requests.get(url)
    soup = bs.BeautifulSoup(source.content, 'html.parser')
    restBlock = soup.find('div', class_='field field-name-field-large-column field-type-text-long field-label-hidden')
    restBlock = restBlock.find('div', class_='field-item even')
    # find the first child of restBlock and convert it to a string and remove weird characters
    restName = restBlock.contents[0].text.strip()
    restName = restName.replace('é', 'e')
    if restName == '':
        restName = restBlock.contents[2].text.strip()
    if '\xa0' in restName:
        restName = restName.replace('\xa0', ' ')
    if restName == 'The MainSqueeze':
        restName = 'The Main Squeeze'
    if restName == "Bing's at Weatherford":
        restName = "Bing's Cafe"
    return restName

# %%
def getMenus(restName, date):
    url = "https://my.uhds.oregonstate.edu/api/dining/weeklymenu/" + rest_site_map[restName]

    source = requests.get(url)
    soup = bs.BeautifulSoup(source.content, 'html.parser')
    weekly = soup.find_all('div', class_='section')

    menus = []
    for today in weekly:
        if date in today.h6.text:
            menu = {}
            menu['title'] = today.h6.text
            menu['items'] = []
            for p in today.find_all('p'):
                menu['items'].append(p.text)
            menus.append(menu)

    return menus

# %%
url = 'https://my.uhds.oregonstate.edu/api/drupal/hours'
response = requests.get(url)
html_content = response.text

soup = bs.BeautifulSoup(html_content, 'html.parser')

buildings = soup.find_all('h1')
restGroups = soup.find('div', class_='pure-g').find_all('div', class_='pure-g')

restaurants = []

for building, restGroup in zip(buildings, restGroups):
    for rest in restGroup.find_all('div', class_='concept_block'):
        building_name = building.text
        url = rest.find('a', class_='concept').get('href')
        
        address = ""
        menus = []

        times_div = rest.find_all('div', class_='time')
        times = []
        for time in times_div:
            times.append(time.text.strip())

        name = rest.find('a', class_='concept').text.strip()
        if '*' not in name:
            name = getRestName(url)
        else:
            restaurants.append({'name': name, 'times': times, 'building': building_name, 'address': address, 'menus': menus})
            continue

        menus = getMenus(name, 'November 07')
        address = getRestAddress(url)
        
        restaurants.append({'name': name, 'times': times, 'building': building_name, 'address': address, 'menus': menus})

display(restaurants)
# Out:
# [{'name': "Trader Bing's Cafe",
#   'times': ['7:30 AM - 6:30 PM'],
#   'building': 'Austin Hall',
#   'address': 'Inside Austin Hall, 2751 SW Jefferson Way, Corvallis, OR 97331',
#   'menus': [{'title': 'BREAKFAST - November 07th',
#     'items': ['Entrepreneur Breakfast Sandwich',
#      'Promotion Breakfast Sandwich',
#      'The Plan Breakfast Sandwich',
#      'TBC Strategic Spin Wrap',
#      'TBC System Execution']},
#    {'title': 'Salads - November 07th',
#     'items': ['Chairman Chicken Caesar Salad',
#      'TBC Side Caesar Salad',
#      "Teri's COO Salad",
#      'TBC Side Salad']},
#    {'title': 'Options to Add - November 07th',
#     'items': ['Balsamic Vinaigrette Dressing ',
#      'Red Onion ',
#      'Tomato ',
#      'Honey Mustard Dressing ',
#      'Grey Poupon Dijon Mustard',
#      'Mayonnaise',
#      'Fresh Mozzarella ',
#      'Avocado ',
#      'Roman Caesar Dressing ',
#      'Cream Cheese ',
#      'Shaved Parmesan',
#      'Chipotle Mayonnaise ',
#      'Roasted Red Pepper ',
#      'Bacon ',
#      'Sliced  White Cheddar Cheese',
#      'Basil Pesto Sauce',
#      'Spreadable Brie']},
#    {'title': 'PROTEIN OPTIONS - November 07th',
#     'items': ['Deli Turkey Breast ',
#      'Deli Ham ',
#      'Bacon ',
#      'Chicken Breast  ']},
#    {'title': 'WRAPS - November 07th',
#     'items': ['Four Pillars Wrap',
#      'Chairman Chicken Caesar Wrap',
#      'The Spicy Executive Wrap']},
#    {'title': 'BAGEL OPTIONS - November 07th',
#     'items': ['Marsee Everything Bagel',
#      'Marsee Asiago Cheese Bagel',
#      'Philadelphia Cream Cheese Cups 100ct',
#      'Marsee Plain Bagel']},
#    {'title': 'SANDWICHES - November 07th',
#     'items': ['Big Board Club Sandwich',
#      'CEO Sandwich',
#      'Stockbroker Sandwich',
#      "Teri's COO Sandwich",
#      'Shameless Sandwich',
#      'Capital Caprese Sandwich']},
#    {'title': 'SIDES - November 07th',
#     'items': ['TBC Half Mac and Cheese',
#      'TBC Mac and Cheese',
#      'TB Avocado Toast',
#      'TBC Side Caesar Salad',
#      'TBC Side Salad']}]},
#  {'name': 'Dixon Cafe',
#   'times': ['10:00 AM - 10:00 PM'],
#   'building': 'Dixon Recreation Center',
#   'address': '425 SW 26th St,, Corvallis, OR 97331',
#   'menus': []},
#  {'name': 'Cascadia Market',
#   'times': ['9:00 AM - 10:00 PM'],
#   'building': 'International Living-Learning Center',
#   'address': 'International Living-Learning Center, 1701 Western Blvd, Corvallis OR 97331',
#   'menus': []},
#  {'name': 'Cascadia Cafe',
#   'times': ['7:30 AM - 6:00 PM'],
#   'building': 'International Living-Learning Center',
#   'address': 'International Living-Learning Center, 1701 SW Western Blvd ,  Corvallis, OR 97331',
#   'menus': []},
#  {'name': 'Cascadia Deli',
#   'times': ['11:00 AM - 9:30 PM'],
#   'building': 'International Living-Learning Center',
#   'address': 'International Living-Learning Center, 1701 Western Blvd, Corvallis OR 97331',
#   'menus': [{'title': 'LUNCH - November 07th',
#     'items': ['Steamed Jasmine Rice',
#      'Oven Roasted Potato Wedges',
#      'Steamed Broccoli',
#      'Brown Rice',
#      'Mandarin Orange Chicken',
#      'Mac and Cheese, Cas',
#      'Orange Ginger Tofu',
#      'Shrimp Tempura',
#      'Capri Blend Vegetables',
#      'Plant Based Chicken Tenders']},
#    {'title': 'DINNER - November 07th',
#     'items': ['Steamed Jasmine Rice',
#      'Oven Roasted Potato Wedges',
#      'Steamed Broccoli',
#      'Brown Rice',
#      'Mandarin Orange Chicken',
#      'Mac and Cheese, Cas',
#      'Orange Ginger Tofu',
#      'Shrimp Tempura',
#      'Capri Blend Vegetables',
#      'Plant Based Chicken Tenders']},
#    {'title': 'Made to Order Sandwich - November 07th',
#     'items': ['Cascadia Club Sandwich ',
#      'Chicken Bacon Ranch Sandwich',
#      'Grilled Cheese, Cas']}]},
#  {'name': 'e.Cafe',
#   'times': ['7:30 AM - 7:00 PM'],
#   'building': 'Kelley Engineering Center',
#   'address': 'Inside Kelley Engineering Center, 2500 NW Monroe Ave, Corvallis, OR 97331',
#   'menus': [{'title': 'BREAKFAST - November 07th',
#     'items': ['Breakfast Binary',
#      'Deli Breakfast Sandwich',
#      'Classic Breakfast Bowl',
#      'eCafe Bypass',
#      'Classic Breakfast Burrito',
#      'Toasted Bagel/Toast with Spread',
#      'Loaded Veggie Breakfast Bowl']},
#    {'title': 'LUNCH - November 07th',
#     'items': ['eCafe Macaroni & White Cheddar Cheese W/Plantfare',
#      'Chicken Basil Binary',
#      'The Capacitor',
#      'Loaded Veggie Burrito',
#      'eCafe Bread Bowl wSoup',
#      'eCafe Bread Bowl wMac and Cheese',
#      'Flux Dip Sandwich',
#      'Robo Reuben Sandwich',
#      'eCafe Analog',
#      'Black Bean Compiler',
#      'Grilled Cheese',
#      'eCafé Gyro ',
#      'eCafe BYO Salad',
#      'The Resistor',
#      'Tesla Turkey Club',
#      'eCafe BYO Sandwich']},
#    {'title': 'PASTRIES - November 07th',
#     'items': ['Marsee Cinnamon Raisin Bagel',
#      'Marsee Everything Bagel',
#      'Plain Bagel ',
#      'Marsee Jalapeno Cheese Bagel',
#      'Marsee Triple Cheese Bagel']},
#    {'title': 'Made to Order Salad - November 07th',
#     'items': ['Buttermilk Ranch Dressing ',
#      'Pepperoncini ',
#      'Balsamic Vinaigrette Dressing ',
#      'Dill Pickle Chip',
#      'Organic Roasted Pumpkin Seeds',
#      'Red Onion ',
#      'Tomato ',
#      'Sliced Swiss Cheese',
#      'Red Bell Pepper ',
#      'Sliced Pepper Jack Cheese ',
#      'Deli Turkey Breast ',
#      'Kronos Hummus',
#      'Sliced Cheddar Cheese',
#      'Chipotle Black Bean Burger Patty',
#      'Chipotle Ranch Dressing ',
#      'Sliced Provolone Cheese',
#      'Cucumber ',
#      'Chicken Breast Strip ',
#      'Deli Ham ',
#      'Cheese & Garlic Croutons',
#      'Feta Cheese Crumbles',
#      'Honey Mustard Dressing ',
#      'Bacon Diced/Bits ',
#      'Vegan Provolone Cheese ']},
#    {'title': 'Made to Order Sandwich - November 07th',
#     'items': ['Buttermilk Ranch Dressing ',
#      'Pepperoncini ',
#      'Dill Pickle Chip',
#      'Red Onion ',
#      'Tomato ',
#      'Sliced Swiss Cheese',
#      'Red Bell Pepper ',
#      'Sliced Pepper Jack Cheese ',
#      'Deli Turkey Breast ',
#      'Kronos Hummus',
#      'Sliced Cheddar Cheese',
#      'Chipotle Black Bean Burger Patty',
#      'Chipotle Ranch Dressing ',
#      'Sliced Provolone Cheese',
#      'Cucumber ',
#      'Chicken Breast Strip ',
#      'Deli Ham ',
#      'Bacon Diced/Bits ',
#      'Vegan Provolone Cheese ',
#      'Yellow Mustard',
#      'Grey Poupon Dijon Mustard',
#      'White Deli Bread Gluten Free ',
#      'Deli White Bread  ',
#      'Wheat Bread ',
#      'Spring Mix Lettuce ',
#      'Swirl Rye Frontier Bread ',
#      'Mayonnaise',
#      'Sourdough Frontier Bread ',
#      'Garlic Herb Tortilla 12"',
#      'Nine Grain Deli Bread ']},
#    {'title': 'SMOOTHIES - November 07th',
#     'items': ['Lemon Berry Blast Smoothie 16oz',
#      'Cyber Berry Smoothie 16oz',
#      'After School Special Smoothie 16oz',
#      'Kinetic Greens Smoothie 16oz',
#      'Orange Vanilla Cream Smoothie 16oz',
#      'Strawberry Lemonade Twist Smoothie 16oz',
#      'PSI Peach Smoothie 16oz',
#      'Peanut Butter Mocha Smoothie 16oz',
#      'Peaches and Cream Smoothie 16oz',
#      'Mechanical Marionberry Smoothie 24oz ',
#      'Strawberry Cream Smoothie 16oz',
#      'Blended Chai 16oz',
#      'Blended Matcha 16oz',
#      'Caramel Blended Coffee 16oz',
#      'Tropical Delight Smoothie 16oz ',
#      'Chocolate Peanut Butter Power Smoothie 16oz',
#      'Sigma Strawberry Smoothie 16oz']}]},
#  {'name': "Ava's Cafe",
#   'times': ['7:30 AM - 5:00 PM'],
#   'building': 'Linus Pauling Science Center',
#   'address': '2900 SW Campus Way,, Corvallis, OR 97330',
#   'menus': []},
#  {'name': 'Coffee Corral',
#   'times': ['7:30 AM - 5:00 PM'],
#   'building': 'Magruder Hall',
#   'address': '700 SW 30th St,',
#   'menus': [{'title': 'BREAKFAST - November 07th',
#     'items': ['The Coop Bagel Sandwich',
#      'Morning in the Paddock Sandwich',
#      'Farmers Market Bagel Sandwich',
#      'Moon Over the Meadow Sandwich',
#      'Toasted Bagel/Toast with Spread']},
#    {'title': 'LUNCH - November 07th',
#     'items': ['TBC Half Mac and Cheese',
#      'TBC Mac and Cheese',
#      'Sandwich Alla Capri',
#      "Ava's Classic Croissant Sandwich",
#      'Coffee Corral Avocado Toast']},
#    {'title': 'PASTRIES - November 07th',
#     'items': ['Chocolate Ring Donut w/ Sprinkles',
#      'Lemon Filled Donut',
#      'Maple Bar Donut',
#      'Butter Croissant']},
#    {'title': 'Made to Order Salad - November 07th',
#     'items': ["The Cluckin' Chicken Salad",
#      'Yard Bird Salad',
#      'Chicks in the Garden Salad',
#      'Caprese Garden Salad']},
#    {'title': 'ADD-ONS - November 07th',
#     'items': ['Deli Turkey Breast ',
#      'Deli Ham ',
#      'Bacon ',
#      'Basil Pesto Sauce',
#      'Chicken Breast  ',
#      'Plant Based Chicken Breast']},
#    {'title': 'SANDWICH BREAD OPTIONS - November 07th',
#     'items': ['Marsee Everything Bagel',
#      'Marsee Asiago Cheese Bagel',
#      'Marsee Plain Bagel',
#      'Whole Wheat Deli Bread ',
#      'Plain Croissant ']},
#    {'title': 'WRAPS - November 07th',
#     'items': ['The Gobbler Wrap',
#      'The Leading Wrap',
#      'Hummingbird Vegan Wrap ']},
#    {'title': 'BAGEL OPTIONS - November 07th',
#     'items': ['Marsee Everything Bagel',
#      'Marsee Asiago Cheese Bagel',
#      'Marsee Plain Bagel']},
#    {'title': 'SIDES - November 07th',
#     'items': ['CC Side Salad', 'Side Caesar Salad']}]},
#  {'name': 'West Side Grill',
#   'times': ['11:00 AM - 8:00 PM'],
#   'building': 'Marketplace West',
#   'address': 'West Dining, 351 SW 30th St, Corvallis OR 97331',
#   'menus': [{'title': 'DINNER - November 07th',
#     'items': ["Cal's Southwest Chicken Sandwich"]},
#    {'title': 'Made to Order Burger - November 07th',
#     'items': ['Buttermilk Ranch Dressing ',
#      'Dill Pickle Chip',
#      'Red Onion ',
#      'Tomato ',
#      'Sliced Swiss Cheese',
#      'Sliced Pepper Jack Cheese ',
#      'Sliced Cheddar Cheese',
#      'Yellow Mustard',
#      'Mayonnaise',
#      'Avocado ',
#      'Halal Grass Fed Beef Patties ',
#      'Wheat Hamburger Bun w/Oat Topping ',
#      'Potato Hamburger Bun ',
#      'Caramelized Yellow Onions',
#      'Fry Sauce',
#      'Green Leaf Lettuce ',
#      'Bacon',
#      'French Fries Skin On',
#      'Tater Tots',
#      'Hamburger Bun, GF ',
#      'Black Bean Burger Patty',
#      'Barbecue Sauce ',
#      'Vegan Cheddar Cheese ',
#      'American Cheese',
#      'Ketchup',
#      'MPW Roasted Mushrooms',
#      'Breaded Chicken Tender ',
#      'Chicken Breast ']},
#    {'title': 'Make Cents - November 07th',
#     'items': ["Make Cents, Cal's Chicken Wrap & Slaw"]}]},
#  {'name': 'Clubhouse Deli',
#   'times': ['7:00 AM - 8:00 PM'],
#   'building': 'Marketplace West',
#   'address': 'West Dining, 351 SW 30th St ,  Corvallis 97331',
#   'menus': [{'title': 'CLUBHOUSE DELI BREAKFAST - November 07th',
#     'items': ['MPW Florentine Breakfast Sandwich',
#      'Ham Bagel Breakfast Sandwich',
#      'Marsee Cinnamon Raisin Bagel',
#      'Marsee Everything Bagel',
#      'Marsee Triple Cheese Bagel',
#      'Marsee Plain Bagel',
#      'Cinnamon Granola, GF/VGN, Red Plate',
#      'Lucky Charms ',
#      'Marsee Multi Grain Bagel',
#      'Raisin Bran Cereal, Malt-O-Meal',
#      'Bacon Bagel Breakfast Sandwich',
#      'Marsee Blueberry Bagel',
#      'Honey Nut Cheerios ',
#      'Cinnamon Toast Crunch ']},
#    {'title': 'CLUBHOUSE DELI SANDWICHES - November 07th',
#     'items': ['Southwest Black Bean Wrap',
#      'Dagwood Sandwich',
#      'Grilled Turkey and Cheddar Sandwich',
#      'Grilled Ham and Swiss Sandwich',
#      'Caprese Sandwich ',
#      'Three Cheese Panino',
#      'Cuban Panino',
#      'Chicken Caesar Wrap',
#      'Mediterranean Panino',
#      'Club Panino ',
#      'Grilled Reuben',
#      'Make Cents, Vegan Chili and Half Cheese Sandwich',
#      'Capri Panino',
#      'Turkey Bacon Avocado Panino']},
#    {'title': 'CLUBHOUSE DELI GRAB & GO - November 07th',
#     'items': ['Gelatin - Assorted Flavors',
#      'Grab and Go Pineapple10oz',
#      'Grab and Go Honeydew 10oz',
#      'Grab and Go Cantaloupe 10oz',
#      'Grab and Go Grapes 6oz',
#      'Grab and Go Fruit Salad w/Watermelon 10oz',
#      'Chocolate Chip Berry Overnight Oats',
#      'Philadelphia Cream Cheese Cups 100ct',
#      'Retail, Blackberry, 6oz',
#      'Retail, Snack Tray - Veggies & Dip, 7oz',
#      'Retail, Seneca Apple Chips 2.5oz',
#      'Navel Orange',
#      'Retail, Blueberry, 6oz',
#      'Grapefruit ',
#      'Retail, Chicken BLT Salad 6.1oz',
#      'Retail, Kickin BBQ Salad 7oz',
#      'Pink Lady Apple',
#      'Retail, Whole Strawberries, 1LB',
#      'Gala Apple',
#      'Kiwi ',
#      'Mango ',
#      'Retail, Seneca Caramel Apple Chips 2.5oz',
#      'Retail, Chicken Caesar Salad, 6.25oz',
#      'Granny Smith Apple',
#      'Philly Strawberry Cream Cheese Cups 1oz 100ct',
#      'Retail, Snack Tray - Pretzels & Cheese, 4.25oz',
#      'Jif Creamy Peanut Butter Cups ',
#      'Light Philadelphia Cream Cheese Cups 100ct',
#      'Smuckers Assorted Jelly Cups 200ct',
#      'Retail, Raspberry, 6oz',
#      'Retail, Snack Tray - Turkey & Cheddar, 6oz',
#      'Banana ',
#      'Fuji Apple',
#      'Bosc Pear',
#      'Retail, Cobb Salad, 7.25oz',
#      'Retail, Asian Style Chopped Salad 6.5oz',
#      'Marionberry Yogurt Parfait',
#      'Retail, Mini Seedless Watermelon',
#      'Retail, Santa Fe Caesar Salad, 6.25oz',
#      'Retail, Seneca Cinnamon Apple Chips 2.5oz',
#      'Anjou Pear',
#      'Retail, Snack Tray - Apples & Cheese, 5.75oz',
#      'Honeycrisp Apple']},
#    {'title': 'CLUBHOUSE DELI SOUPS - November 07th',
#     'items': ['Chicken Noodle Soup - House Made',
#      'House Creamy Vegetable Soup',
#      'Sourdough Round ',
#      'House Potato Corn Soup',
#      'Vegan Chili',
#      'Hungarian Mushroom Soup - House Made',
#      'Lentil & Ham Soup, 541 - House Made',
#      'Clam Chowder',
#      'Broccoli Cheddar Soup - House Made',
#      'Cream of Chicken Soup - House Made',
#      'House Butternut Squash Soup',
#      'Minestrone Soup - House Made',
#      'House Vegetable Barley Soup',
#      'Tomato Soup - House Made',
#      'House Potato Leek Soup',
#      'House Roasted Cauliflower Soup',
#      'House Coconut Curry Soup',
#      'Corn Chowder']},
#    {'title': 'Made to Order Salad - November 07th',
#     'items': ['Scored and Sliced Cucumber',
#      'Sliced Red Onion',
#      'Pepperoncini ',
#      'Balsamic Vinaigrette Dressing ',
#      'Honey Mustard Dressing ',
#      'Bacon Diced/Bits ',
#      'Spring Mix Lettuce ',
#      'Carrots ',
#      'Edamame ',
#      'Shredded Cheddar Cheese',
#      'Sliced Mushrooms ',
#      'Homestyle Ranch Dressing ',
#      'Sliced Black Olives',
#      'Creamy Caesar Dressing ',
#      'Grape Tomato',
#      'Hardcooked Eggs ',
#      'Blue Cheese Dressing ',
#      'Garbanzo Beans, Low Sodium',
#      'Cottage Cheese',
#      'Cut Baby Corn',
#      'Broccoli Florets ',
#      'Spinach ',
#      'Romaine Lettuce ',
#      'Green Peas ',
#      'Soy Marinated Love Strips',
#      'Soy Marinated Tofu',
#      'Seasoned Croutons',
#      'Chow Mein Noodles',
#      'Diced Ham ',
#      'Sliced Pickled Beets',
#      'Quartered Artichoke Hearts',
#      'Red Wine Vinaigrette Metro Dressing ',
#      'Sunflower Seed ',
#      'Dried Cranberries']},
#    {'title': 'Made to Order Sandwich - November 07th',
#     'items': ['Scored and Sliced Cucumber',
#      'Sliced Red Onion',
#      'Sliced Tomato',
#      'Pepperoncini ',
#      'Dill Pickle Chip',
#      'Sliced Swiss Cheese',
#      'Sliced Pepper Jack Cheese ',
#      'Deli Turkey Breast ',
#      'Sliced Cheddar Cheese',
#      'Sliced Provolone Cheese',
#      'Deli Ham ',
#      'Yellow Mustard',
#      'Grey Poupon Dijon Mustard',
#      'White Deli Bread Gluten Free ',
#      'Mayonnaise',
#      'Avocado ',
#      'Roasted Red Pepper ',
#      'Bacon ',
#      'Basil Pesto Sauce',
#      'Sliced Black Olives',
#      'Spinach ',
#      'Flour Tortilla 12"',
#      'Vegan American Cheese ',
#      'Green Leaf Lettuce ',
#      'Kosher Dill Pickle Spear',
#      'Sourdough Sandwich Bread ',
#      'Multigrain Bread, Gluten Free ',
#      'Honey Wheat Bread ',
#      "Garlic Aioli, Ken's",
#      'Spinach Herb Tortilla 12"',
#      'Sliced Mozzarella Cheese',
#      'Vegan Mayonnaise ',
#      'Hard Salami ',
#      'Vegan Chipotle Mayo',
#      'MPW Tuna Salad',
#      'Sliced Ciabatta ',
#      'Egg Salad',
#      'Hummus',
#      'Country White Bread ',
#      'Plain Flatbread ',
#      'Sourdough Rye Sandwich Bread ',
#      'Tomato Basil Tortilla 12"',
#      'Chicken Breast Strip w/Grill Marks ']},
#    {'title': 'CLUBHOUSE DELI SUSHI - November 07th',
#     'items': ['Sushi, Avocado Cucumber Roll',
#      'Sushi, Spicy Tuna Roll',
#      'Sushi, Spicy Shrimp Roll',
#      'Sushi, Shrimp Tempura Roll',
#      'Sushi, Vegetable Roll',
#      'Sushi, California Roll']}]},
#  {'name': "Cooper's Creek",
#   'times': ['10:00 AM - 2:00 PM', '5:00 PM - 8:00 PM'],
#   'building': 'Marketplace West',
#   'address': 'Marketplace West, 351 SW 30th St  , Corvallis, OR 97333',
#   'menus': [{'title': 'LUNCH - November 07th',
#     'items': ['Southwestern Grain Bowl',
#      'Hummus Bowl',
#      'Everest Bowl',
#      'Make Cents, Veggie Protein Plate']},
#    {'title': 'Made to Order Bowl - November 07th',
#     'items': ['Balsamic Dressing',
#      'Flank Steak w/Cilantro Peppercorn Paste',
#      'Roasted Chicken Thigh, Diced',
#      'Garlic Herb Chicken Boneless Thighs',
#      'Grilled Portabella',
#      'Grilled Salmon',
#      'Raspberry Vinaigrette',
#      'Chicken Spice Mix',
#      'Miso Ginger Dressing',
#      'Honey Lime Dressing',
#      'Garlic Tahini Dressing',
#      'Avocado ',
#      'Roasted Red Pepper ',
#      'Lime',
#      'Red Cabbage ',
#      'Grape Tomato',
#      'Roasted Corn ',
#      'Hardcooked Eggs ',
#      'Spinach ',
#      'Cilantro ',
#      'Shredded Carrots ',
#      'Black Beans ',
#      'Hummus',
#      'Steamed Kale',
#      'Cucumber ',
#      'Creamy Chipotle Dressing',
#      'Quinoa Trio Blend w/Turmeric',
#      'Raw Pumpkin Seeds',
#      'Salad Mix, Romaine & Iceberg  50/50',
#      'Pepper Jack Cheese Block',
#      'Blackened Salmon',
#      'Jicama ',
#      'Sharp Cheddar Cheese',
#      'Roasted Yams',
#      'Blackberries ',
#      'Mango Chunks ',
#      'Roasted Vegetable Mix',
#      'Brown Rice',
#      'Gala Apple ',
#      'Pickled Red Onion w/Jalapeno']},
#    {'title': 'BEVERAGE - November 07th', 'items': ['Lemonade']}]},
#  {'name': 'EBGBs',
#   'times': ['7:00 AM - 10:00 PM'],
#   'building': 'Marketplace West',
#   'address': 'Marketplace West Dining Center 351 SW 30th St Corvallis, OR 97331',
#   'menus': []},
#  {'name': 'Ring of Fire',
#   'times': ['11:00 AM - 2:00 PM', '4:00 PM - 9:00 PM'],
#   'building': 'Marketplace West',
#   'address': 'Marketplace West 351 SW 30th St Corvallis 97331',
#   'menus': [{'title': 'RING OF FIRE LUNCH - November 07th',
#     'items': ['Steamed Jasmine Rice',
#      'Teriyaki Sauce',
#      'Teriyaki Marinated Chicken Thighs',
#      'Rice Noodles',
#      'Brown Rice',
#      'Chili Garlic Roasted Broccoli',
#      'Vegetable Pho Broth',
#      'Mandarin Marinated Tofu, 541',
#      'Vegetable Spring Roll, Jade Mountain']},
#    {'title': 'RING OF FIRE DINNER - November 07th',
#     'items': ['Steamed Jasmine Rice',
#      'Teriyaki Sauce',
#      'Teriyaki Marinated Chicken Thighs',
#      'Rice Noodles',
#      'Brown Rice',
#      'Chili Garlic Roasted Broccoli',
#      'Vegetable Pho Broth',
#      'Mandarin Marinated Tofu, 541',
#      'Vegetable Spring Roll, Jade Mountain']},
#    {'title': 'ADD-ONS - November 07th',
#     'items': ['Fukujinzuke',
#      'Jalapeno Pepper ',
#      'Green Onion ',
#      'Mung Bean Sprout',
#      'Cilantro ',
#      'Whole Kernal Corn ',
#      'Shredded Carrots ',
#      'Cucumber ',
#      'Kimchi']},
#    {'title': 'BEVERAGE - November 07th',
#     'items': ['Ring of Fire Thai Iced Tea']}]},
#  {'name': 'Bay Leaf',
#   'times': ['11:00 AM - 3:00 PM', '5:00 PM - 11:00 PM'],
#   'building': 'Marketplace West',
#   'address': 'Marketplace West, 351 SW 30th St, Corvallis, 97331',
#   'menus': [{'title': 'LATE NITE - November 07th',
#     'items': ['Mac & Cheese Side',
#      'Garlic Naan',
#      'Hummus Bowl',
#      'Mozzarella Cheese Sticks',
#      'Homestyle Ranch Dressing ',
#      'Retail, Chicken Caesar Salad, 6.25oz',
#      'Mango Lassi Panna Cotta',
#      'Chocolate Chunk Cookie ',
#      'Nite Bite Veggie Pizza',
#      'Nite Bite Pepperoni Pizza',
#      'Soft Baked Pretzel',
#      'Nite Bite Cheese Pizza',
#      'White Queso Sauce',
#      'Nite Bite Combination Pizza']},
#    {'title': 'BAY LEAF LUNCH - November 07th',
#     'items': ['Pickled Red Onion w/Jalapeno',
#      'Chicken Tikka Masala',
#      'Cucumber and Mint Raita',
#      'Cilantro Chutney',
#      'Steamed Basmati',
#      'Phaal Curry Sauce, 541',
#      'Spicy Tamarind Red Pepper Chutney',
#      'Lentil and Spinach Vadai',
#      'Jalapeno Pepper ',
#      'Red Onion ',
#      'Green Cabbage ',
#      'Cilantro ',
#      'Roma Tomato ',
#      'Cucumber ',
#      'Green Peas ',
#      'Mango ',
#      'Onion Garlic & Cilantro Flatbread',
#      'Lemon Wedge',
#      'Flatbread',
#      'Mango Chutney']},
#    {'title': 'BAY LEAF DINNER - November 07th',
#     'items': ['Grilled Broccolini',
#      'Garlic Herb Chicken Boneless Thighs',
#      'Minestrone Soup - House Made',
#      'Greek Salad',
#      'Roasted Tomato & Artichoke Orzo',
#      'Soy Chicken Love Strip Fajita Meat',
#      'Greek Marinde',
#      'Greek Roasted Potatoes']},
#    {'title': 'DESSERTS - November 07th',
#     'items': ['Cannoli', 'Raspberry Jam']},
#    {'title': 'BAY LEAF BEVERAGE SPECIAL - November 07th',
#     'items': ['Italian Soda',
#      'Italian Soda w/Half & Half',
#      'Vanilla Syrup ',
#      'Raspberry Syrup ',
#      'Salted Caramel Syrup ']},
#    {'title': 'PIZZA STATION - November 07th',
#     'items': ['MPW 4 Cheese Pizza', 'Chicken Piccata Pizza']}]},
#  {'name': 'Serrano Grill',
#   'times': ['7:00 AM - 10:30 AM', '11:30 AM - 2:30 PM', '5:00 PM - 9:00 PM'],
#   'building': 'Marketplace West',
#   'address': 'Marketplace West  351 SW 30th St Corvallis, 97331',
#   'menus': [{'title': 'BREAKFAST - November 07th',
#     'items': ['French Toast',
#      'Buttermilk Biscuit ',
#      'Sausage Breakfast Gravy',
#      'Vegan GF Pancakes ',
#      'Turkey Sausage Patty',
#      'Sausage & Bacon Breakfast Burrito',
#      'Scratch Pancake Batter',
#      'Chilaquiles Verdes',
#      'Huevos Rancheros',
#      'Chocolate Chip Pancake',
#      'Blueberry Pancake',
#      'Corned Beef Hash',
#      'Pork Sausage Breakfast Patty',
#      'Monte Cristo',
#      'Chicken Sausage Links',
#      'Denver Frittata',
#      'Vegetarian Denver Frittata',
#      'Pork Sausage Links',
#      'Vegan Egg Scramble',
#      'Scrambled Eggs w/Ham & Cheese',
#      'Scrambled Eggs',
#      'Bacon',
#      "O'Brien Potatoes",
#      'Veggie Breakfast Burrito',
#      'Maple Pancake and Waffle Syrup',
#      'Croissant Breakfast Sandwich w/Ham',
#      'Butter Chip',
#      'Tofu Scramble']},
#    {'title': 'LUNCH - November 07th',
#     'items': ['Serrano Barbacoa Street Taco',
#      'Serrano Chicken Street Taco',
#      'Hard Shell Soyrizo Tacos ',
#      'Serrano Mushroom Tofu Street Taco',
#      'White Corn Tortilla 6"',
#      'Hard Shell Beef Tacos']},
#    {'title': 'DINNER - November 07th',
#     'items': ['Serrano Cheese Nachos',
#      'Serrano Super Nachos',
#      'French Fries Skin On']},
#    {'title': 'Made to Order Bowl - November 07th',
#     'items': ['Pico de Gallo',
#      'Brown Rice',
#      'Serrano Black Beans',
#      'Barbacoa',
#      'Chicken Tinga',
#      'Lime',
#      'Sliced Pickled Jalapeno',
#      'Lime Crema',
#      'Shredded Cheddar Jack Cheese',
#      'Avocado Salsa',
#      'Flour Tortilla 12"',
#      'Wheat Tortilla 12"',
#      'Tumaro Tortilla 12" GF',
#      'Mango Morita Salsa',
#      'Vegan Cheddar Cheese ',
#      'Chicken w/Guajillo Mole',
#      'Mango Salsa',
#      'Mushroom Tofu Blend',
#      'Salsa Roja',
#      'Cilantro Lime Rice',
#      'Shredded Lettuce ',
#      'Corn and Black Bean Salsa',
#      'MPW Chili de Arbol Salsa']},
#    {'title': 'ADD-ONS - November 07th',
#     'items': ['Mango & Tajin',
#      'Watermelon & Tajin',
#      'Guacamole',
#      'Yellow Corn Tortilla Chip ',
#      'Elote']}]},
#  {'name': 'East Side Eats',
#   'times': ['7:00 AM - 7:30 PM'],
#   'building': 'McNary Dining',
#   'address': 'McNary Dining Center, 1300 SW Jefferson Ave, Corvallis OR 97331',
#   'menus': [{'title': 'BREAKFAST - November 07th',
#     'items': ['Scrambled Eggs',
#      "O'Brien Potatoes",
#      'Scrambled Eggs w/Ham & Cheese',
#      'Oatmeal',
#      'Vegetarian Breakfast Sausage Patty',
#      'Chicken Sausage Links',
#      'Sirniki',
#      'Buckwheat Kasha',
#      'Bacon',
#      'Buttermilk Biscuit ',
#      'Tomato Gravy',
#      'Vegan GF Pancakes ',
#      'Kielbasa Link',
#      'Sausage Breakfast Gravy',
#      'Cream of Wheat']},
#    {'title': 'DINNER - November 07th',
#     'items': ['Pozharsky Cutlet',
#      'Hungarian Bean Goulash ',
#      'Mashed Red Potatoes',
#      'Paprika Red Potatoes',
#      'Szegedin Goulash',
#      'Pretzel Twist ',
#      'Crema Mexicana',
#      'Mushroom Julienne',
#      'Spiced Red Cabbage']},
#    {'title': 'Made to Order/Bar - November 07th',
#     'items': ['Baked Potato',
#      'Baked Sweet Potato',
#      'Bacon',
#      'Green Onion ',
#      'Crema Mexicana',
#      'Pico de Gallo',
#      'Sliced Pickled Jalapeno',
#      'Shredded Cheddar Cheese']},
#    {'title': 'Made to Order Salad - November 07th',
#     'items': ['Balsamic Vinaigrette Dressing ',
#      'Spring Mix Lettuce ',
#      'Shaved Parmesan',
#      'Bacon',
#      'Carrots ',
#      'Red Bell Pepper ',
#      'Sliced Pickled Jalapeno',
#      'Shredded Cheddar Cheese',
#      'Sliced Mushrooms ',
#      'Olivye Salad',
#      'Russian Vinaigrette Salad',
#      'Homestyle Ranch Dressing ',
#      'Fruit Salad',
#      'Sliced Black Olives',
#      'Parsnip',
#      'Creamy Caesar Dressing ',
#      'Grape Tomato',
#      'Roasted Corn ',
#      'Hardcooked Eggs ',
#      'Red Onion ',
#      'Roasted Chicken Thigh, Diced',
#      'Cucumber ',
#      'Romaine Lettuce ',
#      'Blue Cheese Dressing ',
#      'Garbanzo Beans, Low Sodium',
#      'Steamed Broccoli',
#      'Golden Italian Dressing ',
#      'Supreme Thousand Island Dressing ',
#      'Shoestring Pickled Beets']},
#    {'title': 'Made to Order Yogurt/Acai - November 07th',
#     'items': ['Fruit Salad',
#      'Black Chia Seeds ',
#      'Blueberries ',
#      'Plain Greek Yogurt ',
#      'Brown Flax Seed',
#      'Cinnamon Granola, GF/VGN, Red Plate',
#      'Raspberry Yogurt ',
#      'Dried Cherry',
#      'Semi Sweet Chocolate Chips',
#      'GF Old Fashioned Oats ',
#      'Honey Greek Yogurt ',
#      'Cottage Cheese',
#      'Pumpkin Seeds ',
#      'Light Brown Beet Sugar ',
#      'Dried Apricot',
#      'Strawberry Yogurt ',
#      'Low Fat Vanilla Yogurt ',
#      'Peaches ']},
#    {'title': 'STIR FRY - November 07th',
#     'items': ['Edamame ',
#      'Green Onion ',
#      'Sliced Mushrooms ',
#      'Garbanzo Beans, Low Sodium',
#      'Green Cabbage ',
#      'Sweet Thai Chili Sauce',
#      'Ginger Puree',
#      'Snap Peas',
#      'Garlic Clove, AP',
#      'Serrano Chile Stir Fry Sauce',
#      'Carrots ',
#      'Cut Baby Corn',
#      'Bok Choy ',
#      'Yellow Onion ',
#      'Green Bean ',
#      'Orange Sauce ',
#      'Zucchini Squash ',
#      'Cauliflower ',
#      'Szechuan Sauce',
#      'Bell Pepper Tri Color ',
#      'Mung Bean Sprout',
#      'Celery ',
#      'Sweet Teriyaki Sauce',
#      'Broccoli Florets ']},
#    {'title': 'PROTEIN OPTIONS - November 07th',
#     'items': ['Chicken Flavored Soy Strips',
#      'Stir Fry Beef',
#      'Roasted Chicken Thigh, Diced',
#      'Shrimp Stir Fry']},
#    {'title': 'ROTATING SOUPS - November 07th',
#     'items': ['Vegan Chili',
#      'Hungarian Mushroom Soup - House Made',
#      'Borscht']},
#    {'title': 'SIDES - November 07th',
#     'items': ['Chicken Lemongrass Potsticker',
#      'Yakisoba Noodles w/Veggies',
#      'Fried Rice',
#      'Thai Vegetable Spring Roll ',
#      'Pork Bao Bun',
#      'Brown Rice',
#      'Steamed Jasmine Rice']},
#    {'title': 'Make Cents - November 07th',
#     'items': ['Make Cents, Stir Fry w/Chicken',
#      'Make Cents, Stir Fry w/Soy Strips',
#      'MAKE CENTS Beet Jam Toast with Eggs']},
#    {'title': 'Grab & Go - November 07th',
#     'items': ['Grab and Go Peanut Butter & Jelly Sandwich',
#      'Grab and Go Ham & Swiss Sandwich',
#      'Grab and Go Turkey & Cheddar Sandwich',
#      'Grab and Go Chicken Caesar Wrap',
#      'Grab and Go Turkey Club Wrap',
#      'Grab and Go Blueberry Parfait',
#      'Grab and Go Corn & Black Bean Salad 12oz',
#      'Grab and Go Potato Salad 12oz',
#      'Grab and Go Pasta Salad 12oz',
#      'Grab and Go Garden Salad Small',
#      'Grab and Go Hummus & Roasted Vegetable Wrap',
#      'Grab and Go Asian Chicken Salad 12oz',
#      'Grab and Go Fruit Salad 10oz',
#      'Grab and Go Veggie Snack Pack',
#      'Grab and Go Pesto Rotini Salad']}]},
#  {'name': "Calabaloo's",
#   'times': ['11:00 AM - 8:00 PM'],
#   'building': 'McNary Dining',
#   'address': 'McNary Dining Center, 1300 SW Jefferson Ave, Corvallis OR 97331',
#   'menus': [{'title': 'Made to Order Burger - November 07th',
#     'items': ['Black Bean Burger Patty',
#      "Calabaloo's French Fries",
#      "Calabaloo's Chicken Strips",
#      'Beef Patty 3:1',
#      'Cajun Fries',
#      'Truffle Fries',
#      'Red Onion ',
#      'Sliced Swiss Cheese',
#      'Sliced Cheddar Cheese',
#      'Sliced Pickled Jalapeno',
#      'Tomato ',
#      'Hamburger Bun, VGN, GF ',
#      'Wheat Hamburger Bun w/Oat Topping ',
#      'Potato Hamburger Bun ',
#      'Guacamole ',
#      'Vegan American Cheese ',
#      'Grilled Chicken Breast',
#      'Ghost Pepper Habanero Cheese',
#      'Caramelized Yellow Onions',
#      "Calabaloo's Sauteed Mushrooms",
#      'Fry Sauce',
#      'Green Leaf Lettuce ',
#      'Bacon']},
#    {'title': 'ADD-ONS - November 07th',
#     'items': ["Calabaloo's French Fries",
#      'Cajun Fries',
#      'Truffle Fries',
#      'Guacamole ',
#      'Bacon']},
#    {'title': 'Specials / Promos - November 07th',
#     'items': ["Calabaloo's Mediterranean Chicken Sandwich"]},
#    {'title': 'Make Cents - November 07th',
#     'items': ["Make Cents, Cal's Chicken Wrap & Slaw"]},
#    {'title': 'Made to Order Burger - November 07th',
#     'items': ['Black Bean Burger Patty',
#      "Calabaloo's French Fries",
#      "Calabaloo's Chicken Strips",
#      'Beef Patty 3:1',
#      'Cajun Fries',
#      'Truffle Fries',
#      'Red Onion ',
#      'Sliced Swiss Cheese',
#      'Sliced Cheddar Cheese',
#      'Sliced Pickled Jalapeno',
#      'Tomato ',
#      'Hamburger Bun, VGN, GF ',
#      'Wheat Hamburger Bun w/Oat Topping ',
#      'Potato Hamburger Bun ',
#      'Guacamole ',
#      'Vegan American Cheese ',
#      'Grilled Chicken Breast',
#      'Ghost Pepper Habanero Cheese',
#      'Caramelized Yellow Onions',
#      "Calabaloo's Sauteed Mushrooms",
#      'Fry Sauce',
#      'Green Leaf Lettuce ',
#      'Bacon']},
#    {'title': 'ADD-ONS - November 07th',
#     'items': ["Calabaloo's French Fries",
#      'Cajun Fries',
#      'Truffle Fries',
#      'Guacamole ',
#      'Bacon']},
#    {'title': 'Specials / Promos - November 07th',
#     'items': ["Calabaloo's Mediterranean Chicken Sandwich"]},
#    {'title': 'Make Cents - November 07th',
#     'items': ["Make Cents, Cal's Chicken Wrap & Slaw"]}]},
#  {'name': 'The Main Squeeze',
#   'times': ['9:00 AM - 11:30 PM'],
#   'building': 'McNary Dining',
#   'address': 'McNary Dining Center, 1300 SW Jefferson Ave, Corvallis OR 97331',
#   'menus': [{'title': 'SMOOTHIES - November 07th',
#     'items': ['Berry Blast Smoothie 16oz',
#      'Au Naturale Smoothie 16oz',
#      'Au Naturale Smoothie 20oz',
#      'Beach Blast Smoothie 16oz',
#      'Beach Blast Smoothie 20oz',
#      'Berry Getaway Smoothie 20oz',
#      'Invigorator Smoothie 16oz',
#      'Invigorator Smoothie 20oz',
#      'Old School Splash Smoothie 16oz',
#      'Old School Splash Smoothie 20oz',
#      'Pacific Sunset Smoothie 16oz',
#      'Pacific Sunset Smoothie 20oz',
#      'Razzle Dazzle Smoothie 16oz',
#      'Razzle Dazzle Smoothie 20oz',
#      'Revitalista Smoothie 16oz',
#      'Revitalista Smoothie 20oz',
#      'Super Island Splash Smoothie 16oz',
#      'Super Island Splash Smoothie 20oz',
#      'Tropical Escape Smoothie 16oz',
#      'Tropical Escape Smoothie 20oz']}]},
#  {'name': 'Raintree Coffee Co.',
#   'times': ['7:00 AM - 3:00 PM'],
#   'building': 'McNary Dining',
#   'address': 'McNary Dining Center, 1300 SW Jefferson Ave, Corvallis OR 97331',
#   'menus': []},
#  {'name': 'Five Four One',
#   'times': ['10:00 AM - 9:00 PM'],
#   'building': 'McNary Dining',
#   'address': 'McNary Dining Center, 1300 SW Jefferson Ave, Corvallis OR 97331',
#   'menus': [{'title': '541 GRAIN BOWLS - November 07th',
#     'items': ['Fitton Green Bowl, 541']},
#    {'title': '541 SANDWICHES - November 07th',
#     'items': ['541 Chicken Parmesan Sandwich', 'Tempeh Banh Mi']},
#    {'title': '541 PIZZA - November 07th',
#     'items': ['Pepperoni Pizza, 541',
#      'Cheese Pizza, 541',
#      'Chicken Bacon Ranch Pizza, 541',
#      'Oregon Potato Pizza, 541']},
#    {'title': '541 PASTA - November 07th',
#     'items': ['Make Cents, Pasta and Legumes, 541',
#      'Raw Vegetables for Pasta, 541',
#      'Vegan Bolognese',
#      'House Made Pasta, 541',
#      'Pomodoro Sauce, 541',
#      'Garlic Cream Sauce, 541',
#      'Vegan Italian Crumble Sausage ',
#      'Pasta, GF Penne']},
#    {'title': '541 SALADS - November 07th',
#     'items': ['Small House Salad, 541']},
#    {'title': 'Made to Order Bowl - November 07th',
#     'items': ['541 Tzatziki',
#      'Green Lentil Tabbouleh',
#      'Daikon ',
#      'Garbanzo Beans, Low Sodium',
#      'Black Beans ',
#      'Shredded Parmesan',
#      'Organic Green Onion',
#      'Organic Romaine Lettuce ',
#      'Creamy Verde Dressing, 541',
#      'Pickled Organic Onion',
#      'Organic Whole Kernel Corn',
#      'Organic Cucumber',
#      'Buttermilk Ranch Dressing, 541',
#      'Soaked and Steamed Quinoa',
#      'Organic Spinach ',
#      'Organic Matchstick Carrots ',
#      'Organic Lime',
#      'Vegan Caesar Dressing, 541',
#      'Lemon Curry Dressing, 541',
#      'Caesar Dressing, 541',
#      'Organic Cherry Tomato']},
#    {'title': 'ADD-ONS - November 07th',
#     'items': ['Chicken Thigh ',
#      'Ground Pork Sausage',
#      'Lemon Baked Salmon',
#      'BBQ Tempeh',
#      'Organic Avocado ',
#      'Chicken Breast in Strips, Halal']},
#    {'title': 'Made to Order Pizza - November 07th',
#     'items': ['Pomodoro Sauce, 541',
#      'Pizza Dough-6.5oz',
#      'Cilantro Lime Beef, 541',
#      'Honey Cured Bacon ',
#      'Garlic Cream Sauce, 541',
#      'Vegan Italian Crumble Sausage ',
#      'Chicken Breast in Strips, Halal',
#      'Organic Fresh Basil',
#      'Organic Red Bell Pepper',
#      'Grilled Organic Kale',
#      'Organic Sliced White Mushrooms',
#      'Vegan Pepperoni ',
#      'Gluten Free Pizza Crust',
#      'Organic Roma Tomato ',
#      'All Natural Pepperoni  ',
#      'Vegan Mozzarella ',
#      'Shredded Mozzarella Cheese']},
#    {'title': '541 CREPE - November 07th',
#     'items': ['GF Crepe, 541',
#      'Whipped Cream, 541',
#      'Chocolate Hazlenut Crepe, 541',
#      'Organic Strawberries',
#      'Cheesecake Filling for Crepes, 541',
#      'Orange Creamsicle Crepe Filling',
#      'Organic Fresh Blueberries']},
#    {'title': '541 ENTREES - November 07th',
#     'items': ['Pomodoro Sauce, 541',
#      'Cilantro Lime Beef, 541',
#      'House Made Pasta, 541',
#      'Baked Tofu, 541',
#      'Organic Arugula Side Salad',
#      'Caramelized Organic Yellow Onions']},
#    {'title': '541 TOPPINGS - November 07th',
#     'items': ['Organic Fresh Basil',
#      'Organic Italian Parsley',
#      'Grated Parmesan',
#      'Organic Crushed Red Pepper']}]},
#  {'name': 'La Calle',
#   'times': ['8:30 AM - 11:00 AM', '6:30 PM - 9:00 PM'],
#   'building': 'McNary Dining',
#   'address': 'McNary Dining Center, 1300 SW Jefferson Ave, Corvallis OR 97331',
#   'menus': [{'title': 'Made to Order/Bar - November 07th',
#     'items': ['Green Onion ',
#      'Sliced Pickled Jalapeno',
#      'Lime Crema',
#      'Shredded Cheddar Jack Cheese',
#      'Tomato ',
#      'Spinach ',
#      'Radish ',
#      'Cilantro ',
#      'White Onion ']},
#    {'title': 'ADD-ONS - November 07th',
#     'items': ['Sausage Breakfast Gravy',
#      'Guacamole',
#      'Avocado Salsa',
#      'Smoky Red Arbol Salsa',
#      'Chipotle Salsa']},
#    {'title': 'PROTEIN OPTIONS - November 07th',
#     'items': ['Bacon', 'Vegan Chorizo Saute', 'Adobo de Chancho ', 'Chorizo']},
#    {'title': 'TORTILLA OPTIONS - November 07th',
#     'items': ['Yellow Corn Tortilla Chip ',
#      'White Corn Tortilla 6"',
#      'Flour Tortilla 12"',
#      'Wheat Tortilla 12"',
#      'Tumaro Tortilla 12" GF']},
#    {'title': 'SIDES - November 07th',
#     'items': ['Scrambled Eggs',
#      'Steamed Jasmine Rice',
#      'Tofu Scramble',
#      "O'Brien Potatoes",
#      'La Calle Pinto Beans']},
#    {'title': 'Made to Order/Bar - November 07th',
#     'items': ['Jalapeno Pepper ',
#      'Green Cabbage ',
#      'Lime Crema',
#      'Tomato ',
#      'Radish ',
#      'Cilantro ',
#      'White Onion ',
#      'Cotija Cheese',
#      'Pickled Red Onion w/Jalapeno',
#      'Lime Juice ']},
#    {'title': 'ADD-ONS - November 07th',
#     'items': ['White Queso Sauce',
#      'Guacamole',
#      'Avocado Salsa',
#      'Smoky Red Arbol Salsa',
#      'Chipotle Salsa']},
#    {'title': 'PROTEIN OPTIONS - November 07th',
#     'items': ['Jackfruit Carnitas',
#      'Adobo de Chancho ',
#      'Cilantro Lime Beef',
#      'Pollo a la Parrilla']},
#    {'title': 'TORTILLA OPTIONS - November 07th',
#     'items': ['Yellow Corn Tortilla Chip ',
#      'White Corn Tortilla 6"',
#      'Flour Tortilla 12"',
#      'Wheat Tortilla 12"',
#      'Tumaro Tortilla 12" GF',
#      'Telera Roll']},
#    {'title': 'SIDES - November 07th',
#     'items': ['La Calle Pinto Beans',
#      'Corn and Black Bean Saute',
#      'Verde Rice',
#      'Cilantro Lime Rice']}]},
#  {'name': 'Bites',
#   'times': ['7:30 AM - 7:00 PM'],
#   'building': 'Memorial Union',
#   'address': 'Memorial Union, 111 SW Jefferson Way, Corvallis, OR 97331',
#   'menus': []},
#  {'name': 'JavaStop',
#   'times': ['7:30 AM - 7:00 PM'],
#   'building': 'Memorial Union',
#   'address': 'Memorial Union, 111 SW Jefferson Way, Corvallis, OR 97331',
#   'menus': []},
#  {'name': 'Off The Quad',
#   'times': ['9:00 AM - 3:00 PM'],
#   'building': 'Memorial Union',
#   'address': '',
#   'menus': [{'title': 'OFF THE QUAD BEVERAGE - November 07th',
#     'items': ['Rise Juice',
#      'Boost Juice',
#      'Hibiscus Tea',
#      'Fresh Apple Juice',
#      'Fresh Squeezed Orange Juice']},
#    {'title': 'OFF THE QUAD BREAKFAST - November 07th',
#     'items': ['Avocado Toast with Pico de Gallo',
#      'OTQ Bacon Breakfast Burrito',
#      'Biscuit w/Jam and Butter',
#      'OTQ Breakfast Burrito',
#      'Caprese Avocado Toast',
#      'Acai Bowl- Three Berry ',
#      'Avocado Toast W/Bacon',
#      'Banana Bread French Toast',
#      'OTQ Chicken Sausage Breakfast Burrito',
#      'Berry Chocolate Chip Overnight Oats']},
#    {'title': 'OFF THE QUAD LUNCH - November 07th',
#     'items': ['Cheese Panini',
#      'Tomato Soup - House Made',
#      'Pepita Hummus & Pita Plate',
#      'Chile Lime Chicken Burrito',
#      'Pork Carnitas Burrito',
#      'Rajas Veggie Burrito',
#      'Tortilla Chips & Salsa',
#      'Makes Cents, Taco Salad',
#      'OTQ Nachos',
#      'Power Salad',
#      'Cherries & Crema Parfait',
#      'Barbacoa Beef Burrito',
#      'Italian Turkey Sand ',
#      'BLTA',
#      'Falafel Sand W/Roasted Tomato',
#      'Oven Roasted Potato Wedges']},
#    {'title': 'Made to Order Bowl - November 07th',
#     'items': ['Steamed Jasmine Rice',
#      'Sesame Cucumber Salad',
#      'Blanched Broccoli',
#      'Brown Rice',
#      'Avocado Vinaigrette Dressing',
#      'Sweet Soy Sauce',
#      'White Sesame Seeds',
#      'Marinated Yellowfin Tuna',
#      'Lime',
#      'Marinated Salmon',
#      'Fried Garlic',
#      'Red Cabbage ',
#      'OTQ Roasted Chicken Breast',
#      'Carrots ',
#      'Spicy Miso Aioli',
#      'Jalapeno Pepper ',
#      'Edamame ',
#      'Red Bell Pepper ',
#      'Daikon ',
#      'Green Onion ',
#      'Soy Marinated Love Strips',
#      'Romaine Lettuce ',
#      'USE MANGO CUBED   Mango Diced,']}]},
#  {'name': 'Rocket Burger *',
#   'times': ['9:30 AM - 7:00 PM'],
#   'building': 'Memorial Union',
#   'address': '',
#   'menus': []},
#  {'name': 'Happy Lemon *',
#   'times': ['10:00 AM - 7:00 PM'],
#   'building': 'Memorial Union',
#   'address': '',
#   'menus': []},
#  {'name': 'Panda Express *',
#   'times': ['10:00 AM - 8:00 PM'],
#   'building': 'Memorial Union',
#   'address': '',
#   'menus': []},
#  {'name': 'North Porch Cafe',
#   'times': ['10:30 AM - 2:30 PM'],
#   'building': 'Memorial Union',
#   'address': 'Inside\xa0Memorial Union, 2501 SW Jefferson Way, Corvallis, OR 97333',
#   'menus': [{'title': 'LUNCH - November 07th',
#     'items': ['Five Spice Pork Banh Mi',
#      'Asian Tofu Banh Mi',
#      'Thai BBQ Chicken Banh Mi',
#      'Steamed Chicken Potstickers',
#      'Soy Marinated Eggs',
#      'Noodle Salad W/Tofu',
#      'Cucumber & Edamame Salad',
#      'Noodle Salad W/Chicken',
#      'Vegetable Lo Mein']},
#    {'title': 'NP Made to Order BOWL - November 07th',
#     'items': ['Carrots ',
#      'Jalapeno Pepper ',
#      'Edamame ',
#      'Green Onion ',
#      'Cauliflower ',
#      'Mung Bean Sprout',
#      'Broccoli Florets ',
#      'Cilantro ',
#      'Korean Barbecue Sauce',
#      'Five Spice Pork',
#      'Brown Rice',
#      'Wonton Chip',
#      'Kimchi',
#      'Blanched Salted Peanuts',
#      'Yellow Coconut Curry Sauce',
#      'Steamed Jasmine Rice',
#      'Thai BBQ Chicken Thighs',
#      'Red Potato',
#      'Marinated & Roasted Tofu',
#      'Fried Onions ',
#      'Red Coconut Curry Sauce',
#      'Button Mushrooms ']}]},
#  {'name': 'Global Fare',
#   'times': ['7:00 AM - 10:30 AM', '11:00 AM - 2:00 PM', '5:00 PM - 8:00 PM'],
#   'building': 'Southside Station @ Arnold',
#   'address': 'Arnold Bistro, 681 SW 26th, Corvallis OR 97331',
#   'menus': [{'title': 'BREAKFAST - November 07th',
#     'items': ['Scrambled Eggs',
#      'French Toast',
#      "O'Brien Potatoes",
#      'Buttermilk Biscuit ',
#      'Hash Brown Triangles',
#      'Sausage Breakfast Gravy',
#      'Turkey Sausage Patty',
#      'Tofu Scramble with Vegetables',
#      'Vegan "Just Egg" Scramble',
#      'House Made Buttermilk Pancake',
#      'Pork Sausage Links',
#      'Bacon']},
#    {'title': 'LUNCH - November 07th',
#     'items': ['Sushi Rice',
#      'Fried Egg',
#      'Green Onions',
#      'Gochujang Chicken',
#      'Korean Spinach ',
#      'Korean Bean Sprouts',
#      'Bulgogi Mushrooms',
#      'Korean Barbecue Sauce',
#      'Fried Garlic',
#      'Shredded Carrots ',
#      'Kimchi Fried Rice',
#      'Sauteed Shiitake Mushrooms',
#      'Bulgogi Beef']},
#    {'title': 'DINNER - November 07th',
#     'items': ['Sushi Rice',
#      'Fried Egg',
#      'Green Onions',
#      'Gochujang Chicken',
#      'Korean Spinach ',
#      'Korean Bean Sprouts',
#      'Bulgogi Mushrooms',
#      'Korean Barbecue Sauce',
#      'Fried Garlic',
#      'Shredded Carrots ',
#      'Kimchi Fried Rice',
#      'Sauteed Shiitake Mushrooms',
#      'Bulgogi Beef']},
#    {'title': 'Grab & Go - November 07th',
#     'items': ['Country Breakfast Bowl',
#      'Breakfast Burrito with Veggies',
#      'Bacon and Sausage Breakfast Burrito',
#      'Plant Based Breakfast Burrito',
#      'Breakfast Bowl w/Veggies']}]},
#  {'name': 'Nori',
#   'times': ['11:00 AM - 2:30 PM', '5:00 PM - 8:00 PM'],
#   'building': 'Southside Station @ Arnold',
#   'address': 'Arnold Bistro, 681 SW 26th, Corvallis OR 97331',
#   'menus': [{'title': 'NORI GRILL - November 07th',
#     'items': ['Fried Tofu Teriyaki Bowl',
#      'Japanese Vegetable Curry',
#      'Spicy Korean Pork Bowl w/Kimchi',
#      'Chicken Teriyaki Bowl',
#      'Beef Teriyaki Bowl']},
#    {'title': 'Made to Order Bowl - November 07th',
#     'items': ['Soft Poached Egg',
#      'Teriyaki Marinated Chicken Thighs',
#      'Tonkotsu Broth',
#      'Ramen Noodles',
#      'Rice Noodles ',
#      'Green Onions',
#      'Hardcooked Eggs ',
#      'Mung Bean Sprout',
#      'Bamboo Shoot Strips',
#      'Honey Cured Bacon ',
#      'Shitake Mushroom, Dried',
#      'Fried Garlic',
#      'Yakinori Blue Nori',
#      'Tofu ',
#      'Shoyu Broth',
#      'Whole Kernal Corn ',
#      'Miso Broth',
#      'Udon Noodles']},
#    {'title': 'SIDES - November 07th',
#     'items': ['Togarashi Tots',
#      'Vegetable Spring Rolls w/Sweet Chili Sauce',
#      'Pok Pok Wing Sauce',
#      'Pok Pok Chicken Wings']},
#    {'title': 'Make Cents - November 07th',
#     'items': ['Make Cents Teriyaki Chicken and Noodles',
#      'Make Cents Crispy Tofu and Yakisoba Noodles',
#      'Make Cents, Teriyaki Beef and Yakisoba Noodles']},
#    {'title': 'NORI SUSHI - November 07th',
#     'items': ['Sushi, California Roll',
#      'Sushi, Cucumber Avocado Roll',
#      'Sushi, Vegetable Roll']}]},
#  {'name': 'Grill',
#   'times': ['11:00 AM - 7:30 PM'],
#   'building': 'Southside Station @ Arnold',
#   'address': '',
#   'menus': [{'title': 'Made to Order Burger - November 07th',
#     'items': ['Bohemian Black Bean Patty',
#      'Dill Pickle Chip',
#      'Sliced Swiss Cheese',
#      'Sliced Pepper Jack Cheese ',
#      'Sliced Cheddar Cheese',
#      'Sliced Pickled Jalapeno',
#      'Red Onion ',
#      'Lamb Patty',
#      'Vegan Cheddar Cheese ',
#      'Halal Grass Fed Beef Patties ',
#      'Fry Sauce',
#      'Chicken Breast ',
#      'Lettuce ',
#      'Spicy Fry Sauce',
#      'Roma Tomato ',
#      'Hamburger Bun, VGN, GF ',
#      'Wheat Hamburger Bun w/Oat Topping ',
#      'Potato Hamburger Bun ']},
#    {'title': 'ADD-ONS - November 07th',
#     'items': ['Caramelized Yellow Onions',
#      "Calabaloo's French Fries",
#      "Calabaloo's Chicken Strips",
#      "Calabaloo's Sauteed Mushrooms",
#      'Guacamole ',
#      'Pineapple Rings ',
#      'Bacon']},
#    {'title': 'Specials / Promos - November 07th',
#     'items': ["Calabaloo's Cowboy Burger"]},
#    {'title': 'Make Cents - November 07th',
#     'items': ['Make Cents, Chili Cheese Fries']}]},
#  {'name': 'Southside Station Deli',
#   'times': ['10:30 AM - 5:00 PM'],
#   'building': 'Southside Station @ Arnold',
#   'address': 'Arnold Bistro,     681 SW 26th,    Corvallis OR 97331',
#   'menus': [{'title': 'Made to Order Sandwich - November 07th',
#     'items': ['Tuna Salad',
#      'Egg Salad',
#      'Chipotle Mayonnaise',
#      'Chicken Breast in Strips, Halal',
#      'Vegan Chimichurri Mayo',
#      'Pepperoncini ',
#      'Dill Pickle Chip',
#      'Sliced Swiss Cheese',
#      'Sliced Pepper Jack Cheese ',
#      'Deli Turkey Breast ',
#      'Kronos Hummus',
#      'Sliced Cheddar Cheese',
#      'Sliced Provolone Cheese',
#      'Deli Ham ',
#      'Yellow Mustard',
#      'White Deli Bread Gluten Free ',
#      'Wheat Bread ',
#      'Mayonnaise',
#      'Basil Pesto Sauce',
#      'Red Bell Pepper ',
#      'Red Onion ',
#      'Tomato ',
#      'Vegan Cheddar Cheese ',
#      'Lettuce ',
#      'Guacamole ',
#      'Teardrop Naan',
#      'Roast Beef ',
#      'Honey Cured Bacon ',
#      'Eggless Mayonnaise Spread ',
#      'Whole Wheat Hoagie ',
#      'Curved Croissant, 3.7oz',
#      'Hoagie Roll 8" ',
#      'Cucumber ',
#      'Vegan American Cheese ']},
#    {'title': 'SOUP - November 07th',
#     'items': ['Tomato Soup - House Made',
#      'Clam Chowder',
#      'Tuscan Bean Soup w/Pancetta - House Made',
#      'House Potato Corn Soup',
#      'House Country Harvest Tomato & Vegetable Soup',
#      'House Vegetable Barley Soup',
#      'House Wild Rice Vegetable Soup',
#      'Italian Wedding w/Meatballs Soup',
#      'Tuscan Bean Soup - House Made',
#      'House Made Vegetable Beef and Barley Soup',
#      'Lentil & Ham Soup, House Made']},
#    {'title': 'PANINIS - November 07th',
#     'items': ['Cheesesteak Panini',
#      'Mushroom Panini',
#      'Italian Panini',
#      'Hummus & Feta Panini']},
#    {'title': 'Make Cents - November 07th',
#     'items': ['Make Cents, Cheese Pizza Bagel w/Side Salad']},
#    {'title': 'Grab & Go - November 07th',
#     'items': ['Strawberry Yogurt Parfait',
#      'Grab and Go Potato Salad',
#      'Grab and Go Island Mac Salad',
#      'Grab and Go Loaded Potato Salad',
#      'Grab and Go Ham & Swiss Sandwich',
#      'Grab and Go Turkey & Cheddar Sandwich',
#      'Grab and Go Blueberry Parfait',
#      'Grab and Go Fruit Cup 4oz',
#      'Grab and Go Fruit Cup 12oz',
#      'Grab and Go Broccoli Salad 12oz',
#      'Grab and Go Chickpea Salad Sandwich',
#      'Grab and Go Pesto Rotini Salad',
#      'Grab and Go Diced Bacon',
#      'Grab and Go Diced Chicken',
#      'Grab and Go Southwest Vegan Black Bean Wrap']},
#    {'title': 'ARNOLD SALAD BAR - November 07th',
#     'items': ['Roasted Beets',
#      'Roasted Broccoli',
#      "Calabaloo's Sauteed Mushrooms",
#      'Marinated Red Onion',
#      'Roasted Radishes',
#      'Crispy Fried Seasoned Tofu',
#      'Pepperoncini ',
#      'Balsamic Vinaigrette Dressing ',
#      'Feta Cheese Crumbles',
#      'Honey Mustard Dressing ',
#      'Spring Mix Lettuce ',
#      'Carrots ',
#      'Edamame ',
#      'Red Bell Pepper ',
#      'Shredded Cheddar Cheese',
#      'Homestyle Ranch Dressing ',
#      'Creamy Caesar Dressing ',
#      'Grape Tomato',
#      'Hardcooked Eggs ',
#      'Garbanzo Beans, Low Sodium',
#      'Cottage Cheese',
#      'Spinach ',
#      'Whole Kernal Corn ',
#      'Cucumber ',
#      'Whole Baby Corn',
#      'Mandarin Orange Segments ',
#      'Kalamata Olives ',
#      'Romaine Lettuce ',
#      'Black Beans ',
#      'Greggorio Italian Dressing ',
#      'Green Peas ',
#      'Shredded Parmesan',
#      'Sliced Pears in Juice',
#      'Grilled Roasted Artichoke']}]},
#  {'name': 'Southside Station Pizzeria',
#   'times': ['11:30 AM - 1:30 PM', '5:00 PM - 7:00 PM'],
#   'building': 'Southside Station @ Arnold',
#   'address': 'Arnold Bistro, 681 SW 26th, Corvallis OR 97331',
#   'menus': [{'title': 'LUNCH - November 07th',
#     'items': ['Pepperoni Pizza Summer',
#      'Southside Ham & Pineapple Pizza Summer',
#      'Chicken Bacon Artichoke Pizza Summer',
#      'Vegetarian Pizza Summer',
#      'Cheese Pizza Summer']},
#    {'title': 'DINNER - November 07th',
#     'items': ['Pepperoni Pizza Summer',
#      'Southside Ham & Pineapple Pizza Summer',
#      'Chicken Bacon Artichoke Pizza Summer',
#      'Vegetarian Pizza Summer',
#      'Cheese Pizza Summer']},
#    {'title': 'Specials / Promos - November 07th', 'items': ['Meatball Pizza']},
#    {'title': 'PIZZA STATION - November 07th',
#     'items': ['Cheese Pizza', 'Pepperoni Pizza', 'Vegetarian Pizza']}]},
#  {'name': 'The Dam',
#   'times': ['7:30 AM - 6:30 PM'],
#   'building': 'The Learning Innovation Center',
#   'address': 'Inside Learning Innovation Center, 165 SW Sackett Pl, Corvallis, OR 97331',
#   'menus': []},
#  {'name': 'Java II',
#   'times': ['7:30 AM - 10:00 PM'],
#   'building': 'Valley Library',
#   'address': 'Inside The Valley Library, 121 The Valley Library, Corvallis, OR 97331',
#   'menus': []},
#  {'name': "Bing's Cafe",
#   'times': ['7:30 AM - 8:00 PM'],
#   'building': 'Weatherford Hall',
#   'address': 'Weatherford Hall, 300 SW 26th St, Corvallis OR 97331',
#   'menus': []}]

# %%
with open('restaurants.json', 'w') as f:
    json.dump(restaurants, f, indent=4)

# %%
from datetime import datetime

class DiningScraper:
    def __init__(self, date=None):
        if date is None:
            date = datetime.now().strftime('%B %d')
        self.date = date
        self.rest_site_map = self.get_rest_site_map()
        self.restaurants = self.scrape_restaurants()
    
    def get_rest_site_map(self):
        menus = {}
        url = "https://my.uhds.oregonstate.edu/api/dining/weeklymenu/1"
        response = requests.get(url)
        soup = bs.BeautifulSoup(response.text, 'html.parser')
        locations = soup.find('select', id='locations')
        options = locations.find_all('option')
        for option in options:
            location = option.text.strip()
            location = location.replace('é', 'e')
            value = option['value']
            menus[location] = value
        return menus
    
    def get_rest_address(self, url):
        response = requests.get(url)
        soup = bs.BeautifulSoup(response.text, 'html.parser')
        location = soup.find('p', string=re.compile('Location')).find_next_sibling('p').text.strip().replace('\n', ', ').replace('\t', '')
        return location
    
    def get_rest_name(self, url):
        source = requests.get(url)
        soup = bs.BeautifulSoup(source.content, 'html.parser')
        restBlock = soup.find('div', class_='field field-name-field-large-column field-type-text-long field-label-hidden')
        restBlock = restBlock.find('div', class_='field-item even')
        restName = restBlock.contents[0].text.strip()
        restName = restName.replace('é', 'e')
        if restName == '':
            restName = restBlock.contents[2].text.strip()
        if '\xa0' in restName:
            restName = restName.replace('\xa0', ' ')
        if restName == 'The MainSqueeze':
            restName = 'The Main Squeeze'
        if restName == "Bing's at Weatherford":
            restName = "Bing's Cafe"
        return restName
    
    def get_menus(self, restName):
        url = "https://my.uhds.oregonstate.edu/api/dining/weeklymenu/" + self.rest_site_map[restName]
        source = requests.get(url)
        soup = bs.BeautifulSoup(source.content, 'html.parser')
        weekly = soup.find_all('div', class_='section')
        menus = []
        for today in weekly:
            if self.date in today.h6.text:
                menu = {}
                menu['title'] = today.h6.text
                menu['items'] = []
                for p in today.find_all('p'):
                    menu['items'].append(p.text)
                menus.append(menu)
        return menus
    
    def scrape_restaurants(self):
        url = 'https://my.uhds.oregonstate.edu/api/drupal/hours'
        response = requests.get(url)
        html_content = response.text
        soup = bs.BeautifulSoup(html_content, 'html.parser')
        buildings = soup.find_all('h1')
        restGroups = soup.find('div', class_='pure-g').find_all('div', class_='pure-g')
        restaurants = []
        for building, restGroup in zip(buildings, restGroups):
            for rest in restGroup.find_all('div', class_='concept_block'):
                building_name = building.text
                url = rest.find('a', class_='concept').get('href')
                address = ""
                menus = []
                times_div = rest.find_all('div', class_='time')
                times = []
                for time in times_div:
                    times.append(time.text.strip())
                name = rest.find('a', class_='concept').text.strip()
                if '*' not in name:
                    name = self.get_rest_name(url)
                else:
                    restaurants.append({
                        'name': name,
                        'times': times,
                        'building': building_name,
                        'address': address,
                        'menus': menus
                    })
                    continue
                menus = self.get_menus(name)
                address = self.get_rest_address(url)
                restaurants.append({
                    'name': name,
                    'times': times,
                    'building': building_name,
                    'address': address,
                    'menus': menus
                })
        return restaurants
    
    scraper = DiningScraper()
    display(scraper.restaurants)
# Out:
# [{'name': "Trader Bing's Cafe",
#   'times': ['7:30 AM - 6:30 PM'],
#   'building': 'Austin Hall',
#   'address': 'Inside Austin Hall, 2751 SW Jefferson Way, Corvallis, OR 97331',
#   'menus': [{'title': 'BREAKFAST - November 07th',
#     'items': ['Entrepreneur Breakfast Sandwich',
#      'Promotion Breakfast Sandwich',
#      'The Plan Breakfast Sandwich',
#      'TBC Strategic Spin Wrap',
#      'TBC System Execution']},
#    {'title': 'Salads - November 07th',
#     'items': ['Chairman Chicken Caesar Salad',
#      'TBC Side Caesar Salad',
#      "Teri's COO Salad",
#      'TBC Side Salad']},
#    {'title': 'Options to Add - November 07th',
#     'items': ['Balsamic Vinaigrette Dressing ',
#      'Red Onion ',
#      'Tomato ',
#      'Honey Mustard Dressing ',
#      'Grey Poupon Dijon Mustard',
#      'Mayonnaise',
#      'Fresh Mozzarella ',
#      'Avocado ',
#      'Roman Caesar Dressing ',
#      'Cream Cheese ',
#      'Shaved Parmesan',
#      'Chipotle Mayonnaise ',
#      'Roasted Red Pepper ',
#      'Bacon ',
#      'Sliced  White Cheddar Cheese',
#      'Basil Pesto Sauce',
#      'Spreadable Brie']},
#    {'title': 'PROTEIN OPTIONS - November 07th',
#     'items': ['Deli Turkey Breast ',
#      'Deli Ham ',
#      'Bacon ',
#      'Chicken Breast  ']},
#    {'title': 'WRAPS - November 07th',
#     'items': ['Four Pillars Wrap',
#      'Chairman Chicken Caesar Wrap',
#      'The Spicy Executive Wrap']},
#    {'title': 'BAGEL OPTIONS - November 07th',
#     'items': ['Marsee Everything Bagel',
#      'Marsee Asiago Cheese Bagel',
#      'Philadelphia Cream Cheese Cups 100ct',
#      'Marsee Plain Bagel']},
#    {'title': 'SANDWICHES - November 07th',
#     'items': ['Big Board Club Sandwich',
#      'CEO Sandwich',
#      'Stockbroker Sandwich',
#      "Teri's COO Sandwich",
#      'Shameless Sandwich',
#      'Capital Caprese Sandwich']},
#    {'title': 'SIDES - November 07th',
#     'items': ['TBC Half Mac and Cheese',
#      'TBC Mac and Cheese',
#      'TB Avocado Toast',
#      'TBC Side Caesar Salad',
#      'TBC Side Salad']}]},
#  {'name': 'Dixon Cafe',
#   'times': ['10:00 AM - 10:00 PM'],
#   'building': 'Dixon Recreation Center',
#   'address': '425 SW 26th St,, Corvallis, OR 97331',
#   'menus': []},
#  {'name': 'Cascadia Market',
#   'times': ['9:00 AM - 10:00 PM'],
#   'building': 'International Living-Learning Center',
#   'address': 'International Living-Learning Center, 1701 Western Blvd, Corvallis OR 97331',
#   'menus': []},
#  {'name': 'Cascadia Cafe',
#   'times': ['7:30 AM - 6:00 PM'],
#   'building': 'International Living-Learning Center',
#   'address': 'International Living-Learning Center, 1701 SW Western Blvd ,  Corvallis, OR 97331',
#   'menus': []},
#  {'name': 'Cascadia Deli',
#   'times': ['11:00 AM - 9:30 PM'],
#   'building': 'International Living-Learning Center',
#   'address': 'International Living-Learning Center, 1701 Western Blvd, Corvallis OR 97331',
#   'menus': [{'title': 'LUNCH - November 07th',
#     'items': ['Steamed Jasmine Rice',
#      'Oven Roasted Potato Wedges',
#      'Steamed Broccoli',
#      'Brown Rice',
#      'Mandarin Orange Chicken',
#      'Mac and Cheese, Cas',
#      'Orange Ginger Tofu',
#      'Shrimp Tempura',
#      'Capri Blend Vegetables',
#      'Plant Based Chicken Tenders']},
#    {'title': 'DINNER - November 07th',
#     'items': ['Steamed Jasmine Rice',
#      'Oven Roasted Potato Wedges',
#      'Steamed Broccoli',
#      'Brown Rice',
#      'Mandarin Orange Chicken',
#      'Mac and Cheese, Cas',
#      'Orange Ginger Tofu',
#      'Shrimp Tempura',
#      'Capri Blend Vegetables',
#      'Plant Based Chicken Tenders']},
#    {'title': 'Made to Order Sandwich - November 07th',
#     'items': ['Cascadia Club Sandwich ',
#      'Chicken Bacon Ranch Sandwich',
#      'Grilled Cheese, Cas']}]},
#  {'name': 'e.Cafe',
#   'times': ['7:30 AM - 7:00 PM'],
#   'building': 'Kelley Engineering Center',
#   'address': 'Inside Kelley Engineering Center, 2500 NW Monroe Ave, Corvallis, OR 97331',
#   'menus': [{'title': 'BREAKFAST - November 07th',
#     'items': ['Breakfast Binary',
#      'Deli Breakfast Sandwich',
#      'Classic Breakfast Bowl',
#      'eCafe Bypass',
#      'Classic Breakfast Burrito',
#      'Toasted Bagel/Toast with Spread',
#      'Loaded Veggie Breakfast Bowl']},
#    {'title': 'LUNCH - November 07th',
#     'items': ['eCafe Macaroni & White Cheddar Cheese W/Plantfare',
#      'Chicken Basil Binary',
#      'The Capacitor',
#      'Loaded Veggie Burrito',
#      'eCafe Bread Bowl wSoup',
#      'eCafe Bread Bowl wMac and Cheese',
#      'Flux Dip Sandwich',
#      'Robo Reuben Sandwich',
#      'eCafe Analog',
#      'Black Bean Compiler',
#      'Grilled Cheese',
#      'eCafé Gyro ',
#      'eCafe BYO Salad',
#      'The Resistor',
#      'Tesla Turkey Club',
#      'eCafe BYO Sandwich']},
#    {'title': 'PASTRIES - November 07th',
#     'items': ['Marsee Cinnamon Raisin Bagel',
#      'Marsee Everything Bagel',
#      'Plain Bagel ',
#      'Marsee Jalapeno Cheese Bagel',
#      'Marsee Triple Cheese Bagel']},
#    {'title': 'Made to Order Salad - November 07th',
#     'items': ['Buttermilk Ranch Dressing ',
#      'Pepperoncini ',
#      'Balsamic Vinaigrette Dressing ',
#      'Dill Pickle Chip',
#      'Organic Roasted Pumpkin Seeds',
#      'Red Onion ',
#      'Tomato ',
#      'Sliced Swiss Cheese',
#      'Red Bell Pepper ',
#      'Sliced Pepper Jack Cheese ',
#      'Deli Turkey Breast ',
#      'Kronos Hummus',
#      'Sliced Cheddar Cheese',
#      'Chipotle Black Bean Burger Patty',
#      'Chipotle Ranch Dressing ',
#      'Sliced Provolone Cheese',
#      'Cucumber ',
#      'Chicken Breast Strip ',
#      'Deli Ham ',
#      'Cheese & Garlic Croutons',
#      'Feta Cheese Crumbles',
#      'Honey Mustard Dressing ',
#      'Bacon Diced/Bits ',
#      'Vegan Provolone Cheese ']},
#    {'title': 'Made to Order Sandwich - November 07th',
#     'items': ['Buttermilk Ranch Dressing ',
#      'Pepperoncini ',
#      'Dill Pickle Chip',
#      'Red Onion ',
#      'Tomato ',
#      'Sliced Swiss Cheese',
#      'Red Bell Pepper ',
#      'Sliced Pepper Jack Cheese ',
#      'Deli Turkey Breast ',
#      'Kronos Hummus',
#      'Sliced Cheddar Cheese',
#      'Chipotle Black Bean Burger Patty',
#      'Chipotle Ranch Dressing ',
#      'Sliced Provolone Cheese',
#      'Cucumber ',
#      'Chicken Breast Strip ',
#      'Deli Ham ',
#      'Bacon Diced/Bits ',
#      'Vegan Provolone Cheese ',
#      'Yellow Mustard',
#      'Grey Poupon Dijon Mustard',
#      'White Deli Bread Gluten Free ',
#      'Deli White Bread  ',
#      'Wheat Bread ',
#      'Spring Mix Lettuce ',
#      'Swirl Rye Frontier Bread ',
#      'Mayonnaise',
#      'Sourdough Frontier Bread ',
#      'Garlic Herb Tortilla 12"',
#      'Nine Grain Deli Bread ']},
#    {'title': 'SMOOTHIES - November 07th',
#     'items': ['Lemon Berry Blast Smoothie 16oz',
#      'Cyber Berry Smoothie 16oz',
#      'After School Special Smoothie 16oz',
#      'Kinetic Greens Smoothie 16oz',
#      'Orange Vanilla Cream Smoothie 16oz',
#      'Strawberry Lemonade Twist Smoothie 16oz',
#      'PSI Peach Smoothie 16oz',
#      'Peanut Butter Mocha Smoothie 16oz',
#      'Peaches and Cream Smoothie 16oz',
#      'Mechanical Marionberry Smoothie 24oz ',
#      'Strawberry Cream Smoothie 16oz',
#      'Blended Chai 16oz',
#      'Blended Matcha 16oz',
#      'Caramel Blended Coffee 16oz',
#      'Tropical Delight Smoothie 16oz ',
#      'Chocolate Peanut Butter Power Smoothie 16oz',
#      'Sigma Strawberry Smoothie 16oz']}]},
#  {'name': "Ava's Cafe",
#   'times': ['7:30 AM - 5:00 PM'],
#   'building': 'Linus Pauling Science Center',
#   'address': '2900 SW Campus Way,, Corvallis, OR 97330',
#   'menus': []},
#  {'name': 'Coffee Corral',
#   'times': ['7:30 AM - 5:00 PM'],
#   'building': 'Magruder Hall',
#   'address': '700 SW 30th St,',
#   'menus': [{'title': 'BREAKFAST - November 07th',
#     'items': ['The Coop Bagel Sandwich',
#      'Morning in the Paddock Sandwich',
#      'Farmers Market Bagel Sandwich',
#      'Moon Over the Meadow Sandwich',
#      'Toasted Bagel/Toast with Spread']},
#    {'title': 'LUNCH - November 07th',
#     'items': ['TBC Half Mac and Cheese',
#      'TBC Mac and Cheese',
#      'Sandwich Alla Capri',
#      "Ava's Classic Croissant Sandwich",
#      'Coffee Corral Avocado Toast']},
#    {'title': 'PASTRIES - November 07th',
#     'items': ['Chocolate Ring Donut w/ Sprinkles',
#      'Lemon Filled Donut',
#      'Maple Bar Donut',
#      'Butter Croissant']},
#    {'title': 'Made to Order Salad - November 07th',
#     'items': ["The Cluckin' Chicken Salad",
#      'Yard Bird Salad',
#      'Chicks in the Garden Salad',
#      'Caprese Garden Salad']},
#    {'title': 'ADD-ONS - November 07th',
#     'items': ['Deli Turkey Breast ',
#      'Deli Ham ',
#      'Bacon ',
#      'Basil Pesto Sauce',
#      'Chicken Breast  ',
#      'Plant Based Chicken Breast']},
#    {'title': 'SANDWICH BREAD OPTIONS - November 07th',
#     'items': ['Marsee Everything Bagel',
#      'Marsee Asiago Cheese Bagel',
#      'Marsee Plain Bagel',
#      'Whole Wheat Deli Bread ',
#      'Plain Croissant ']},
#    {'title': 'WRAPS - November 07th',
#     'items': ['The Gobbler Wrap',
#      'The Leading Wrap',
#      'Hummingbird Vegan Wrap ']},
#    {'title': 'BAGEL OPTIONS - November 07th',
#     'items': ['Marsee Everything Bagel',
#      'Marsee Asiago Cheese Bagel',
#      'Marsee Plain Bagel']},
#    {'title': 'SIDES - November 07th',
#     'items': ['CC Side Salad', 'Side Caesar Salad']}]},
#  {'name': 'West Side Grill',
#   'times': ['11:00 AM - 8:00 PM'],
#   'building': 'Marketplace West',
#   'address': 'West Dining, 351 SW 30th St, Corvallis OR 97331',
#   'menus': [{'title': 'DINNER - November 07th',
#     'items': ["Cal's Southwest Chicken Sandwich"]},
#    {'title': 'Made to Order Burger - November 07th',
#     'items': ['Buttermilk Ranch Dressing ',
#      'Dill Pickle Chip',
#      'Red Onion ',
#      'Tomato ',
#      'Sliced Swiss Cheese',
#      'Sliced Pepper Jack Cheese ',
#      'Sliced Cheddar Cheese',
#      'Yellow Mustard',
#      'Mayonnaise',
#      'Avocado ',
#      'Halal Grass Fed Beef Patties ',
#      'Wheat Hamburger Bun w/Oat Topping ',
#      'Potato Hamburger Bun ',
#      'Caramelized Yellow Onions',
#      'Fry Sauce',
#      'Green Leaf Lettuce ',
#      'Bacon',
#      'French Fries Skin On',
#      'Tater Tots',
#      'Hamburger Bun, GF ',
#      'Black Bean Burger Patty',
#      'Barbecue Sauce ',
#      'Vegan Cheddar Cheese ',
#      'American Cheese',
#      'Ketchup',
#      'MPW Roasted Mushrooms',
#      'Breaded Chicken Tender ',
#      'Chicken Breast ']},
#    {'title': 'Make Cents - November 07th',
#     'items': ["Make Cents, Cal's Chicken Wrap & Slaw"]}]},
#  {'name': 'Clubhouse Deli',
#   'times': ['7:00 AM - 8:00 PM'],
#   'building': 'Marketplace West',
#   'address': 'West Dining, 351 SW 30th St ,  Corvallis 97331',
#   'menus': [{'title': 'CLUBHOUSE DELI BREAKFAST - November 07th',
#     'items': ['MPW Florentine Breakfast Sandwich',
#      'Ham Bagel Breakfast Sandwich',
#      'Marsee Cinnamon Raisin Bagel',
#      'Marsee Everything Bagel',
#      'Marsee Triple Cheese Bagel',
#      'Marsee Plain Bagel',
#      'Cinnamon Granola, GF/VGN, Red Plate',
#      'Lucky Charms ',
#      'Marsee Multi Grain Bagel',
#      'Raisin Bran Cereal, Malt-O-Meal',
#      'Bacon Bagel Breakfast Sandwich',
#      'Marsee Blueberry Bagel',
#      'Honey Nut Cheerios ',
#      'Cinnamon Toast Crunch ']},
#    {'title': 'CLUBHOUSE DELI SANDWICHES - November 07th',
#     'items': ['Southwest Black Bean Wrap',
#      'Dagwood Sandwich',
#      'Grilled Turkey and Cheddar Sandwich',
#      'Grilled Ham and Swiss Sandwich',
#      'Caprese Sandwich ',
#      'Three Cheese Panino',
#      'Cuban Panino',
#      'Chicken Caesar Wrap',
#      'Mediterranean Panino',
#      'Club Panino ',
#      'Grilled Reuben',
#      'Make Cents, Vegan Chili and Half Cheese Sandwich',
#      'Capri Panino',
#      'Turkey Bacon Avocado Panino']},
#    {'title': 'CLUBHOUSE DELI GRAB & GO - November 07th',
#     'items': ['Gelatin - Assorted Flavors',
#      'Grab and Go Pineapple10oz',
#      'Grab and Go Honeydew 10oz',
#      'Grab and Go Cantaloupe 10oz',
#      'Grab and Go Grapes 6oz',
#      'Grab and Go Fruit Salad w/Watermelon 10oz',
#      'Chocolate Chip Berry Overnight Oats',
#      'Philadelphia Cream Cheese Cups 100ct',
#      'Retail, Blackberry, 6oz',
#      'Retail, Snack Tray - Veggies & Dip, 7oz',
#      'Retail, Seneca Apple Chips 2.5oz',
#      'Navel Orange',
#      'Retail, Blueberry, 6oz',
#      'Grapefruit ',
#      'Retail, Chicken BLT Salad 6.1oz',
#      'Retail, Kickin BBQ Salad 7oz',
#      'Pink Lady Apple',
#      'Retail, Whole Strawberries, 1LB',
#      'Gala Apple',
#      'Kiwi ',
#      'Mango ',
#      'Retail, Seneca Caramel Apple Chips 2.5oz',
#      'Retail, Chicken Caesar Salad, 6.25oz',
#      'Granny Smith Apple',
#      'Philly Strawberry Cream Cheese Cups 1oz 100ct',
#      'Retail, Snack Tray - Pretzels & Cheese, 4.25oz',
#      'Jif Creamy Peanut Butter Cups ',
#      'Light Philadelphia Cream Cheese Cups 100ct',
#      'Smuckers Assorted Jelly Cups 200ct',
#      'Retail, Raspberry, 6oz',
#      'Retail, Snack Tray - Turkey & Cheddar, 6oz',
#      'Banana ',
#      'Fuji Apple',
#      'Bosc Pear',
#      'Retail, Cobb Salad, 7.25oz',
#      'Retail, Asian Style Chopped Salad 6.5oz',
#      'Marionberry Yogurt Parfait',
#      'Retail, Mini Seedless Watermelon',
#      'Retail, Santa Fe Caesar Salad, 6.25oz',
#      'Retail, Seneca Cinnamon Apple Chips 2.5oz',
#      'Anjou Pear',
#      'Retail, Snack Tray - Apples & Cheese, 5.75oz',
#      'Honeycrisp Apple']},
#    {'title': 'CLUBHOUSE DELI SOUPS - November 07th',
#     'items': ['Chicken Noodle Soup - House Made',
#      'House Creamy Vegetable Soup',
#      'Sourdough Round ',
#      'House Potato Corn Soup',
#      'Vegan Chili',
#      'Hungarian Mushroom Soup - House Made',
#      'Lentil & Ham Soup, 541 - House Made',
#      'Clam Chowder',
#      'Broccoli Cheddar Soup - House Made',
#      'Cream of Chicken Soup - House Made',
#      'House Butternut Squash Soup',
#      'Minestrone Soup - House Made',
#      'House Vegetable Barley Soup',
#      'Tomato Soup - House Made',
#      'House Potato Leek Soup',
#      'House Roasted Cauliflower Soup',
#      'House Coconut Curry Soup',
#      'Corn Chowder']},
#    {'title': 'Made to Order Salad - November 07th',
#     'items': ['Scored and Sliced Cucumber',
#      'Sliced Red Onion',
#      'Pepperoncini ',
#      'Balsamic Vinaigrette Dressing ',
#      'Honey Mustard Dressing ',
#      'Bacon Diced/Bits ',
#      'Spring Mix Lettuce ',
#      'Carrots ',
#      'Edamame ',
#      'Shredded Cheddar Cheese',
#      'Sliced Mushrooms ',
#      'Homestyle Ranch Dressing ',
#      'Sliced Black Olives',
#      'Creamy Caesar Dressing ',
#      'Grape Tomato',
#      'Hardcooked Eggs ',
#      'Blue Cheese Dressing ',
#      'Garbanzo Beans, Low Sodium',
#      'Cottage Cheese',
#      'Cut Baby Corn',
#      'Broccoli Florets ',
#      'Spinach ',
#      'Romaine Lettuce ',
#      'Green Peas ',
#      'Soy Marinated Love Strips',
#      'Soy Marinated Tofu',
#      'Seasoned Croutons',
#      'Chow Mein Noodles',
#      'Diced Ham ',
#      'Sliced Pickled Beets',
#      'Quartered Artichoke Hearts',
#      'Red Wine Vinaigrette Metro Dressing ',
#      'Sunflower Seed ',
#      'Dried Cranberries']},
#    {'title': 'Made to Order Sandwich - November 07th',
#     'items': ['Scored and Sliced Cucumber',
#      'Sliced Red Onion',
#      'Sliced Tomato',
#      'Pepperoncini ',
#      'Dill Pickle Chip',
#      'Sliced Swiss Cheese',
#      'Sliced Pepper Jack Cheese ',
#      'Deli Turkey Breast ',
#      'Sliced Cheddar Cheese',
#      'Sliced Provolone Cheese',
#      'Deli Ham ',
#      'Yellow Mustard',
#      'Grey Poupon Dijon Mustard',
#      'White Deli Bread Gluten Free ',
#      'Mayonnaise',
#      'Avocado ',
#      'Roasted Red Pepper ',
#      'Bacon ',
#      'Basil Pesto Sauce',
#      'Sliced Black Olives',
#      'Spinach ',
#      'Flour Tortilla 12"',
#      'Vegan American Cheese ',
#      'Green Leaf Lettuce ',
#      'Kosher Dill Pickle Spear',
#      'Sourdough Sandwich Bread ',
#      'Multigrain Bread, Gluten Free ',
#      'Honey Wheat Bread ',
#      "Garlic Aioli, Ken's",
#      'Spinach Herb Tortilla 12"',
#      'Sliced Mozzarella Cheese',
#      'Vegan Mayonnaise ',
#      'Hard Salami ',
#      'Vegan Chipotle Mayo',
#      'MPW Tuna Salad',
#      'Sliced Ciabatta ',
#      'Egg Salad',
#      'Hummus',
#      'Country White Bread ',
#      'Plain Flatbread ',
#      'Sourdough Rye Sandwich Bread ',
#      'Tomato Basil Tortilla 12"',
#      'Chicken Breast Strip w/Grill Marks ']},
#    {'title': 'CLUBHOUSE DELI SUSHI - November 07th',
#     'items': ['Sushi, Avocado Cucumber Roll',
#      'Sushi, Spicy Tuna Roll',
#      'Sushi, Spicy Shrimp Roll',
#      'Sushi, Shrimp Tempura Roll',
#      'Sushi, Vegetable Roll',
#      'Sushi, California Roll']}]},
#  {'name': "Cooper's Creek",
#   'times': ['10:00 AM - 2:00 PM', '5:00 PM - 8:00 PM'],
#   'building': 'Marketplace West',
#   'address': 'Marketplace West, 351 SW 30th St  , Corvallis, OR 97333',
#   'menus': [{'title': 'LUNCH - November 07th',
#     'items': ['Southwestern Grain Bowl',
#      'Hummus Bowl',
#      'Everest Bowl',
#      'Make Cents, Veggie Protein Plate']},
#    {'title': 'Made to Order Bowl - November 07th',
#     'items': ['Balsamic Dressing',
#      'Flank Steak w/Cilantro Peppercorn Paste',
#      'Roasted Chicken Thigh, Diced',
#      'Garlic Herb Chicken Boneless Thighs',
#      'Grilled Portabella',
#      'Grilled Salmon',
#      'Raspberry Vinaigrette',
#      'Chicken Spice Mix',
#      'Miso Ginger Dressing',
#      'Honey Lime Dressing',
#      'Garlic Tahini Dressing',
#      'Avocado ',
#      'Roasted Red Pepper ',
#      'Lime',
#      'Red Cabbage ',
#      'Grape Tomato',
#      'Roasted Corn ',
#      'Hardcooked Eggs ',
#      'Spinach ',
#      'Cilantro ',
#      'Shredded Carrots ',
#      'Black Beans ',
#      'Hummus',
#      'Steamed Kale',
#      'Cucumber ',
#      'Creamy Chipotle Dressing',
#      'Quinoa Trio Blend w/Turmeric',
#      'Raw Pumpkin Seeds',
#      'Salad Mix, Romaine & Iceberg  50/50',
#      'Pepper Jack Cheese Block',
#      'Blackened Salmon',
#      'Jicama ',
#      'Sharp Cheddar Cheese',
#      'Roasted Yams',
#      'Blackberries ',
#      'Mango Chunks ',
#      'Roasted Vegetable Mix',
#      'Brown Rice',
#      'Gala Apple ',
#      'Pickled Red Onion w/Jalapeno']},
#    {'title': 'BEVERAGE - November 07th', 'items': ['Lemonade']}]},
#  {'name': 'EBGBs',
#   'times': ['7:00 AM - 10:00 PM'],
#   'building': 'Marketplace West',
#   'address': 'Marketplace West Dining Center 351 SW 30th St Corvallis, OR 97331',
#   'menus': []},
#  {'name': 'Ring of Fire',
#   'times': ['11:00 AM - 2:00 PM', '4:00 PM - 9:00 PM'],
#   'building': 'Marketplace West',
#   'address': 'Marketplace West 351 SW 30th St Corvallis 97331',
#   'menus': [{'title': 'RING OF FIRE LUNCH - November 07th',
#     'items': ['Steamed Jasmine Rice',
#      'Teriyaki Sauce',
#      'Teriyaki Marinated Chicken Thighs',
#      'Rice Noodles',
#      'Brown Rice',
#      'Chili Garlic Roasted Broccoli',
#      'Vegetable Pho Broth',
#      'Mandarin Marinated Tofu, 541',
#      'Vegetable Spring Roll, Jade Mountain']},
#    {'title': 'RING OF FIRE DINNER - November 07th',
#     'items': ['Steamed Jasmine Rice',
#      'Teriyaki Sauce',
#      'Teriyaki Marinated Chicken Thighs',
#      'Rice Noodles',
#      'Brown Rice',
#      'Chili Garlic Roasted Broccoli',
#      'Vegetable Pho Broth',
#      'Mandarin Marinated Tofu, 541',
#      'Vegetable Spring Roll, Jade Mountain']},
#    {'title': 'ADD-ONS - November 07th',
#     'items': ['Fukujinzuke',
#      'Jalapeno Pepper ',
#      'Green Onion ',
#      'Mung Bean Sprout',
#      'Cilantro ',
#      'Whole Kernal Corn ',
#      'Shredded Carrots ',
#      'Cucumber ',
#      'Kimchi']},
#    {'title': 'BEVERAGE - November 07th',
#     'items': ['Ring of Fire Thai Iced Tea']}]},
#  {'name': 'Bay Leaf',
#   'times': ['11:00 AM - 3:00 PM', '5:00 PM - 11:00 PM'],
#   'building': 'Marketplace West',
#   'address': 'Marketplace West, 351 SW 30th St, Corvallis, 97331',
#   'menus': [{'title': 'LATE NITE - November 07th',
#     'items': ['Mac & Cheese Side',
#      'Garlic Naan',
#      'Hummus Bowl',
#      'Mozzarella Cheese Sticks',
#      'Homestyle Ranch Dressing ',
#      'Retail, Chicken Caesar Salad, 6.25oz',
#      'Mango Lassi Panna Cotta',
#      'Chocolate Chunk Cookie ',
#      'Nite Bite Veggie Pizza',
#      'Nite Bite Pepperoni Pizza',
#      'Soft Baked Pretzel',
#      'Nite Bite Cheese Pizza',
#      'White Queso Sauce',
#      'Nite Bite Combination Pizza']},
#    {'title': 'BAY LEAF LUNCH - November 07th',
#     'items': ['Pickled Red Onion w/Jalapeno',
#      'Chicken Tikka Masala',
#      'Cucumber and Mint Raita',
#      'Cilantro Chutney',
#      'Steamed Basmati',
#      'Phaal Curry Sauce, 541',
#      'Spicy Tamarind Red Pepper Chutney',
#      'Lentil and Spinach Vadai',
#      'Jalapeno Pepper ',
#      'Red Onion ',
#      'Green Cabbage ',
#      'Cilantro ',
#      'Roma Tomato ',
#      'Cucumber ',
#      'Green Peas ',
#      'Mango ',
#      'Onion Garlic & Cilantro Flatbread',
#      'Lemon Wedge',
#      'Flatbread',
#      'Mango Chutney']},
#    {'title': 'BAY LEAF DINNER - November 07th',
#     'items': ['Grilled Broccolini',
#      'Garlic Herb Chicken Boneless Thighs',
#      'Minestrone Soup - House Made',
#      'Greek Salad',
#      'Roasted Tomato & Artichoke Orzo',
#      'Soy Chicken Love Strip Fajita Meat',
#      'Greek Marinde',
#      'Greek Roasted Potatoes']},
#    {'title': 'DESSERTS - November 07th',
#     'items': ['Cannoli', 'Raspberry Jam']},
#    {'title': 'BAY LEAF BEVERAGE SPECIAL - November 07th',
#     'items': ['Italian Soda',
#      'Italian Soda w/Half & Half',
#      'Vanilla Syrup ',
#      'Raspberry Syrup ',
#      'Salted Caramel Syrup ']},
#    {'title': 'PIZZA STATION - November 07th',
#     'items': ['MPW 4 Cheese Pizza', 'Chicken Piccata Pizza']}]},
#  {'name': 'Serrano Grill',
#   'times': ['7:00 AM - 10:30 AM', '11:30 AM - 2:30 PM', '5:00 PM - 9:00 PM'],
#   'building': 'Marketplace West',
#   'address': 'Marketplace West  351 SW 30th St Corvallis, 97331',
#   'menus': [{'title': 'BREAKFAST - November 07th',
#     'items': ['French Toast',
#      'Buttermilk Biscuit ',
#      'Sausage Breakfast Gravy',
#      'Vegan GF Pancakes ',
#      'Turkey Sausage Patty',
#      'Sausage & Bacon Breakfast Burrito',
#      'Scratch Pancake Batter',
#      'Chilaquiles Verdes',
#      'Huevos Rancheros',
#      'Chocolate Chip Pancake',
#      'Blueberry Pancake',
#      'Corned Beef Hash',
#      'Pork Sausage Breakfast Patty',
#      'Monte Cristo',
#      'Chicken Sausage Links',
#      'Denver Frittata',
#      'Vegetarian Denver Frittata',
#      'Pork Sausage Links',
#      'Vegan Egg Scramble',
#      'Scrambled Eggs w/Ham & Cheese',
#      'Scrambled Eggs',
#      'Bacon',
#      "O'Brien Potatoes",
#      'Veggie Breakfast Burrito',
#      'Maple Pancake and Waffle Syrup',
#      'Croissant Breakfast Sandwich w/Ham',
#      'Butter Chip',
#      'Tofu Scramble']},
#    {'title': 'LUNCH - November 07th',
#     'items': ['Serrano Barbacoa Street Taco',
#      'Serrano Chicken Street Taco',
#      'Hard Shell Soyrizo Tacos ',
#      'Serrano Mushroom Tofu Street Taco',
#      'White Corn Tortilla 6"',
#      'Hard Shell Beef Tacos']},
#    {'title': 'DINNER - November 07th',
#     'items': ['Serrano Cheese Nachos',
#      'Serrano Super Nachos',
#      'French Fries Skin On']},
#    {'title': 'Made to Order Bowl - November 07th',
#     'items': ['Pico de Gallo',
#      'Brown Rice',
#      'Serrano Black Beans',
#      'Barbacoa',
#      'Chicken Tinga',
#      'Lime',
#      'Sliced Pickled Jalapeno',
#      'Lime Crema',
#      'Shredded Cheddar Jack Cheese',
#      'Avocado Salsa',
#      'Flour Tortilla 12"',
#      'Wheat Tortilla 12"',
#      'Tumaro Tortilla 12" GF',
#      'Mango Morita Salsa',
#      'Vegan Cheddar Cheese ',
#      'Chicken w/Guajillo Mole',
#      'Mango Salsa',
#      'Mushroom Tofu Blend',
#      'Salsa Roja',
#      'Cilantro Lime Rice',
#      'Shredded Lettuce ',
#      'Corn and Black Bean Salsa',
#      'MPW Chili de Arbol Salsa']},
#    {'title': 'ADD-ONS - November 07th',
#     'items': ['Mango & Tajin',
#      'Watermelon & Tajin',
#      'Guacamole',
#      'Yellow Corn Tortilla Chip ',
#      'Elote']}]},
#  {'name': 'East Side Eats',
#   'times': ['7:00 AM - 7:30 PM'],
#   'building': 'McNary Dining',
#   'address': 'McNary Dining Center, 1300 SW Jefferson Ave, Corvallis OR 97331',
#   'menus': [{'title': 'BREAKFAST - November 07th',
#     'items': ['Scrambled Eggs',
#      "O'Brien Potatoes",
#      'Scrambled Eggs w/Ham & Cheese',
#      'Oatmeal',
#      'Vegetarian Breakfast Sausage Patty',
#      'Chicken Sausage Links',
#      'Sirniki',
#      'Buckwheat Kasha',
#      'Bacon',
#      'Buttermilk Biscuit ',
#      'Tomato Gravy',
#      'Vegan GF Pancakes ',
#      'Kielbasa Link',
#      'Sausage Breakfast Gravy',
#      'Cream of Wheat']},
#    {'title': 'DINNER - November 07th',
#     'items': ['Pozharsky Cutlet',
#      'Hungarian Bean Goulash ',
#      'Mashed Red Potatoes',
#      'Paprika Red Potatoes',
#      'Szegedin Goulash',
#      'Pretzel Twist ',
#      'Crema Mexicana',
#      'Mushroom Julienne',
#      'Spiced Red Cabbage']},
#    {'title': 'Made to Order/Bar - November 07th',
#     'items': ['Baked Potato',
#      'Baked Sweet Potato',
#      'Bacon',
#      'Green Onion ',
#      'Crema Mexicana',
#      'Pico de Gallo',
#      'Sliced Pickled Jalapeno',
#      'Shredded Cheddar Cheese']},
#    {'title': 'Made to Order Salad - November 07th',
#     'items': ['Balsamic Vinaigrette Dressing ',
#      'Spring Mix Lettuce ',
#      'Shaved Parmesan',
#      'Bacon',
#      'Carrots ',
#      'Red Bell Pepper ',
#      'Sliced Pickled Jalapeno',
#      'Shredded Cheddar Cheese',
#      'Sliced Mushrooms ',
#      'Olivye Salad',
#      'Russian Vinaigrette Salad',
#      'Homestyle Ranch Dressing ',
#      'Fruit Salad',
#      'Sliced Black Olives',
#      'Parsnip',
#      'Creamy Caesar Dressing ',
#      'Grape Tomato',
#      'Roasted Corn ',
#      'Hardcooked Eggs ',
#      'Red Onion ',
#      'Roasted Chicken Thigh, Diced',
#      'Cucumber ',
#      'Romaine Lettuce ',
#      'Blue Cheese Dressing ',
#      'Garbanzo Beans, Low Sodium',
#      'Steamed Broccoli',
#      'Golden Italian Dressing ',
#      'Supreme Thousand Island Dressing ',
#      'Shoestring Pickled Beets']},
#    {'title': 'Made to Order Yogurt/Acai - November 07th',
#     'items': ['Fruit Salad',
#      'Black Chia Seeds ',
#      'Blueberries ',
#      'Plain Greek Yogurt ',
#      'Brown Flax Seed',
#      'Cinnamon Granola, GF/VGN, Red Plate',
#      'Raspberry Yogurt ',
#      'Dried Cherry',
#      'Semi Sweet Chocolate Chips',
#      'GF Old Fashioned Oats ',
#      'Honey Greek Yogurt ',
#      'Cottage Cheese',
#      'Pumpkin Seeds ',
#      'Light Brown Beet Sugar ',
#      'Dried Apricot',
#      'Strawberry Yogurt ',
#      'Low Fat Vanilla Yogurt ',
#      'Peaches ']},
#    {'title': 'STIR FRY - November 07th',
#     'items': ['Edamame ',
#      'Green Onion ',
#      'Sliced Mushrooms ',
#      'Garbanzo Beans, Low Sodium',
#      'Green Cabbage ',
#      'Sweet Thai Chili Sauce',
#      'Ginger Puree',
#      'Snap Peas',
#      'Garlic Clove, AP',
#      'Serrano Chile Stir Fry Sauce',
#      'Carrots ',
#      'Cut Baby Corn',
#      'Bok Choy ',
#      'Yellow Onion ',
#      'Green Bean ',
#      'Orange Sauce ',
#      'Zucchini Squash ',
#      'Cauliflower ',
#      'Szechuan Sauce',
#      'Bell Pepper Tri Color ',
#      'Mung Bean Sprout',
#      'Celery ',
#      'Sweet Teriyaki Sauce',
#      'Broccoli Florets ']},
#    {'title': 'PROTEIN OPTIONS - November 07th',
#     'items': ['Chicken Flavored Soy Strips',
#      'Stir Fry Beef',
#      'Roasted Chicken Thigh, Diced',
#      'Shrimp Stir Fry']},
#    {'title': 'ROTATING SOUPS - November 07th',
#     'items': ['Vegan Chili',
#      'Hungarian Mushroom Soup - House Made',
#      'Borscht']},
#    {'title': 'SIDES - November 07th',
#     'items': ['Chicken Lemongrass Potsticker',
#      'Yakisoba Noodles w/Veggies',
#      'Fried Rice',
#      'Thai Vegetable Spring Roll ',
#      'Pork Bao Bun',
#      'Brown Rice',
#      'Steamed Jasmine Rice']},
#    {'title': 'Make Cents - November 07th',
#     'items': ['Make Cents, Stir Fry w/Chicken',
#      'Make Cents, Stir Fry w/Soy Strips',
#      'MAKE CENTS Beet Jam Toast with Eggs']},
#    {'title': 'Grab & Go - November 07th',
#     'items': ['Grab and Go Peanut Butter & Jelly Sandwich',
#      'Grab and Go Ham & Swiss Sandwich',
#      'Grab and Go Turkey & Cheddar Sandwich',
#      'Grab and Go Chicken Caesar Wrap',
#      'Grab and Go Turkey Club Wrap',
#      'Grab and Go Blueberry Parfait',
#      'Grab and Go Corn & Black Bean Salad 12oz',
#      'Grab and Go Potato Salad 12oz',
#      'Grab and Go Pasta Salad 12oz',
#      'Grab and Go Garden Salad Small',
#      'Grab and Go Hummus & Roasted Vegetable Wrap',
#      'Grab and Go Asian Chicken Salad 12oz',
#      'Grab and Go Fruit Salad 10oz',
#      'Grab and Go Veggie Snack Pack',
#      'Grab and Go Pesto Rotini Salad']}]},
#  {'name': "Calabaloo's",
#   'times': ['11:00 AM - 8:00 PM'],
#   'building': 'McNary Dining',
#   'address': 'McNary Dining Center, 1300 SW Jefferson Ave, Corvallis OR 97331',
#   'menus': [{'title': 'Made to Order Burger - November 07th',
#     'items': ['Black Bean Burger Patty',
#      "Calabaloo's French Fries",
#      "Calabaloo's Chicken Strips",
#      'Beef Patty 3:1',
#      'Cajun Fries',
#      'Truffle Fries',
#      'Red Onion ',
#      'Sliced Swiss Cheese',
#      'Sliced Cheddar Cheese',
#      'Sliced Pickled Jalapeno',
#      'Tomato ',
#      'Hamburger Bun, VGN, GF ',
#      'Wheat Hamburger Bun w/Oat Topping ',
#      'Potato Hamburger Bun ',
#      'Guacamole ',
#      'Vegan American Cheese ',
#      'Grilled Chicken Breast',
#      'Ghost Pepper Habanero Cheese',
#      'Caramelized Yellow Onions',
#      "Calabaloo's Sauteed Mushrooms",
#      'Fry Sauce',
#      'Green Leaf Lettuce ',
#      'Bacon']},
#    {'title': 'ADD-ONS - November 07th',
#     'items': ["Calabaloo's French Fries",
#      'Cajun Fries',
#      'Truffle Fries',
#      'Guacamole ',
#      'Bacon']},
#    {'title': 'Specials / Promos - November 07th',
#     'items': ["Calabaloo's Mediterranean Chicken Sandwich"]},
#    {'title': 'Make Cents - November 07th',
#     'items': ["Make Cents, Cal's Chicken Wrap & Slaw"]},
#    {'title': 'Made to Order Burger - November 07th',
#     'items': ['Black Bean Burger Patty',
#      "Calabaloo's French Fries",
#      "Calabaloo's Chicken Strips",
#      'Beef Patty 3:1',
#      'Cajun Fries',
#      'Truffle Fries',
#      'Red Onion ',
#      'Sliced Swiss Cheese',
#      'Sliced Cheddar Cheese',
#      'Sliced Pickled Jalapeno',
#      'Tomato ',
#      'Hamburger Bun, VGN, GF ',
#      'Wheat Hamburger Bun w/Oat Topping ',
#      'Potato Hamburger Bun ',
#      'Guacamole ',
#      'Vegan American Cheese ',
#      'Grilled Chicken Breast',
#      'Ghost Pepper Habanero Cheese',
#      'Caramelized Yellow Onions',
#      "Calabaloo's Sauteed Mushrooms",
#      'Fry Sauce',
#      'Green Leaf Lettuce ',
#      'Bacon']},
#    {'title': 'ADD-ONS - November 07th',
#     'items': ["Calabaloo's French Fries",
#      'Cajun Fries',
#      'Truffle Fries',
#      'Guacamole ',
#      'Bacon']},
#    {'title': 'Specials / Promos - November 07th',
#     'items': ["Calabaloo's Mediterranean Chicken Sandwich"]},
#    {'title': 'Make Cents - November 07th',
#     'items': ["Make Cents, Cal's Chicken Wrap & Slaw"]}]},
#  {'name': 'The Main Squeeze',
#   'times': ['9:00 AM - 11:30 PM'],
#   'building': 'McNary Dining',
#   'address': 'McNary Dining Center, 1300 SW Jefferson Ave, Corvallis OR 97331',
#   'menus': [{'title': 'SMOOTHIES - November 07th',
#     'items': ['Berry Blast Smoothie 16oz',
#      'Au Naturale Smoothie 16oz',
#      'Au Naturale Smoothie 20oz',
#      'Beach Blast Smoothie 16oz',
#      'Beach Blast Smoothie 20oz',
#      'Berry Getaway Smoothie 20oz',
#      'Invigorator Smoothie 16oz',
#      'Invigorator Smoothie 20oz',
#      'Old School Splash Smoothie 16oz',
#      'Old School Splash Smoothie 20oz',
#      'Pacific Sunset Smoothie 16oz',
#      'Pacific Sunset Smoothie 20oz',
#      'Razzle Dazzle Smoothie 16oz',
#      'Razzle Dazzle Smoothie 20oz',
#      'Revitalista Smoothie 16oz',
#      'Revitalista Smoothie 20oz',
#      'Super Island Splash Smoothie 16oz',
#      'Super Island Splash Smoothie 20oz',
#      'Tropical Escape Smoothie 16oz',
#      'Tropical Escape Smoothie 20oz']}]},
#  {'name': 'Raintree Coffee Co.',
#   'times': ['7:00 AM - 3:00 PM'],
#   'building': 'McNary Dining',
#   'address': 'McNary Dining Center, 1300 SW Jefferson Ave, Corvallis OR 97331',
#   'menus': []},
#  {'name': 'Five Four One',
#   'times': ['10:00 AM - 9:00 PM'],
#   'building': 'McNary Dining',
#   'address': 'McNary Dining Center, 1300 SW Jefferson Ave, Corvallis OR 97331',
#   'menus': [{'title': '541 GRAIN BOWLS - November 07th',
#     'items': ['Fitton Green Bowl, 541']},
#    {'title': '541 SANDWICHES - November 07th',
#     'items': ['541 Chicken Parmesan Sandwich', 'Tempeh Banh Mi']},
#    {'title': '541 PIZZA - November 07th',
#     'items': ['Pepperoni Pizza, 541',
#      'Cheese Pizza, 541',
#      'Chicken Bacon Ranch Pizza, 541',
#      'Oregon Potato Pizza, 541']},
#    {'title': '541 PASTA - November 07th',
#     'items': ['Make Cents, Pasta and Legumes, 541',
#      'Raw Vegetables for Pasta, 541',
#      'Vegan Bolognese',
#      'House Made Pasta, 541',
#      'Pomodoro Sauce, 541',
#      'Garlic Cream Sauce, 541',
#      'Vegan Italian Crumble Sausage ',
#      'Pasta, GF Penne']},
#    {'title': '541 SALADS - November 07th',
#     'items': ['Small House Salad, 541']},
#    {'title': 'Made to Order Bowl - November 07th',
#     'items': ['541 Tzatziki',
#      'Green Lentil Tabbouleh',
#      'Daikon ',
#      'Garbanzo Beans, Low Sodium',
#      'Black Beans ',
#      'Shredded Parmesan',
#      'Organic Green Onion',
#      'Organic Romaine Lettuce ',
#      'Creamy Verde Dressing, 541',
#      'Pickled Organic Onion',
#      'Organic Whole Kernel Corn',
#      'Organic Cucumber',
#      'Buttermilk Ranch Dressing, 541',
#      'Soaked and Steamed Quinoa',
#      'Organic Spinach ',
#      'Organic Matchstick Carrots ',
#      'Organic Lime',
#      'Vegan Caesar Dressing, 541',
#      'Lemon Curry Dressing, 541',
#      'Caesar Dressing, 541',
#      'Organic Cherry Tomato']},
#    {'title': 'ADD-ONS - November 07th',
#     'items': ['Chicken Thigh ',
#      'Ground Pork Sausage',
#      'Lemon Baked Salmon',
#      'BBQ Tempeh',
#      'Organic Avocado ',
#      'Chicken Breast in Strips, Halal']},
#    {'title': 'Made to Order Pizza - November 07th',
#     'items': ['Pomodoro Sauce, 541',
#      'Pizza Dough-6.5oz',
#      'Cilantro Lime Beef, 541',
#      'Honey Cured Bacon ',
#      'Garlic Cream Sauce, 541',
#      'Vegan Italian Crumble Sausage ',
#      'Chicken Breast in Strips, Halal',
#      'Organic Fresh Basil',
#      'Organic Red Bell Pepper',
#      'Grilled Organic Kale',
#      'Organic Sliced White Mushrooms',
#      'Vegan Pepperoni ',
#      'Gluten Free Pizza Crust',
#      'Organic Roma Tomato ',
#      'All Natural Pepperoni  ',
#      'Vegan Mozzarella ',
#      'Shredded Mozzarella Cheese']},
#    {'title': '541 CREPE - November 07th',
#     'items': ['GF Crepe, 541',
#      'Whipped Cream, 541',
#      'Chocolate Hazlenut Crepe, 541',
#      'Organic Strawberries',
#      'Cheesecake Filling for Crepes, 541',
#      'Orange Creamsicle Crepe Filling',
#      'Organic Fresh Blueberries']},
#    {'title': '541 ENTREES - November 07th',
#     'items': ['Pomodoro Sauce, 541',
#      'Cilantro Lime Beef, 541',
#      'House Made Pasta, 541',
#      'Baked Tofu, 541',
#      'Organic Arugula Side Salad',
#      'Caramelized Organic Yellow Onions']},
#    {'title': '541 TOPPINGS - November 07th',
#     'items': ['Organic Fresh Basil',
#      'Organic Italian Parsley',
#      'Grated Parmesan',
#      'Organic Crushed Red Pepper']}]},
#  {'name': 'La Calle',
#   'times': ['8:30 AM - 11:00 AM', '6:30 PM - 9:00 PM'],
#   'building': 'McNary Dining',
#   'address': 'McNary Dining Center, 1300 SW Jefferson Ave, Corvallis OR 97331',
#   'menus': [{'title': 'Made to Order/Bar - November 07th',
#     'items': ['Green Onion ',
#      'Sliced Pickled Jalapeno',
#      'Lime Crema',
#      'Shredded Cheddar Jack Cheese',
#      'Tomato ',
#      'Spinach ',
#      'Radish ',
#      'Cilantro ',
#      'White Onion ']},
#    {'title': 'ADD-ONS - November 07th',
#     'items': ['Sausage Breakfast Gravy',
#      'Guacamole',
#      'Avocado Salsa',
#      'Smoky Red Arbol Salsa',
#      'Chipotle Salsa']},
#    {'title': 'PROTEIN OPTIONS - November 07th',
#     'items': ['Bacon', 'Vegan Chorizo Saute', 'Adobo de Chancho ', 'Chorizo']},
#    {'title': 'TORTILLA OPTIONS - November 07th',
#     'items': ['Yellow Corn Tortilla Chip ',
#      'White Corn Tortilla 6"',
#      'Flour Tortilla 12"',
#      'Wheat Tortilla 12"',
#      'Tumaro Tortilla 12" GF']},
#    {'title': 'SIDES - November 07th',
#     'items': ['Scrambled Eggs',
#      'Steamed Jasmine Rice',
#      'Tofu Scramble',
#      "O'Brien Potatoes",
#      'La Calle Pinto Beans']},
#    {'title': 'Made to Order/Bar - November 07th',
#     'items': ['Jalapeno Pepper ',
#      'Green Cabbage ',
#      'Lime Crema',
#      'Tomato ',
#      'Radish ',
#      'Cilantro ',
#      'White Onion ',
#      'Cotija Cheese',
#      'Pickled Red Onion w/Jalapeno',
#      'Lime Juice ']},
#    {'title': 'ADD-ONS - November 07th',
#     'items': ['White Queso Sauce',
#      'Guacamole',
#      'Avocado Salsa',
#      'Smoky Red Arbol Salsa',
#      'Chipotle Salsa']},
#    {'title': 'PROTEIN OPTIONS - November 07th',
#     'items': ['Jackfruit Carnitas',
#      'Adobo de Chancho ',
#      'Cilantro Lime Beef',
#      'Pollo a la Parrilla']},
#    {'title': 'TORTILLA OPTIONS - November 07th',
#     'items': ['Yellow Corn Tortilla Chip ',
#      'White Corn Tortilla 6"',
#      'Flour Tortilla 12"',
#      'Wheat Tortilla 12"',
#      'Tumaro Tortilla 12" GF',
#      'Telera Roll']},
#    {'title': 'SIDES - November 07th',
#     'items': ['La Calle Pinto Beans',
#      'Corn and Black Bean Saute',
#      'Verde Rice',
#      'Cilantro Lime Rice']}]},
#  {'name': 'Bites',
#   'times': ['7:30 AM - 7:00 PM'],
#   'building': 'Memorial Union',
#   'address': 'Memorial Union, 111 SW Jefferson Way, Corvallis, OR 97331',
#   'menus': []},
#  {'name': 'JavaStop',
#   'times': ['7:30 AM - 7:00 PM'],
#   'building': 'Memorial Union',
#   'address': 'Memorial Union, 111 SW Jefferson Way, Corvallis, OR 97331',
#   'menus': []},
#  {'name': 'Off The Quad',
#   'times': ['9:00 AM - 3:00 PM'],
#   'building': 'Memorial Union',
#   'address': '',
#   'menus': [{'title': 'OFF THE QUAD BEVERAGE - November 07th',
#     'items': ['Rise Juice',
#      'Boost Juice',
#      'Hibiscus Tea',
#      'Fresh Apple Juice',
#      'Fresh Squeezed Orange Juice']},
#    {'title': 'OFF THE QUAD BREAKFAST - November 07th',
#     'items': ['Avocado Toast with Pico de Gallo',
#      'OTQ Bacon Breakfast Burrito',
#      'Biscuit w/Jam and Butter',
#      'OTQ Breakfast Burrito',
#      'Caprese Avocado Toast',
#      'Acai Bowl- Three Berry ',
#      'Avocado Toast W/Bacon',
#      'Banana Bread French Toast',
#      'OTQ Chicken Sausage Breakfast Burrito',
#      'Berry Chocolate Chip Overnight Oats']},
#    {'title': 'OFF THE QUAD LUNCH - November 07th',
#     'items': ['Cheese Panini',
#      'Tomato Soup - House Made',
#      'Pepita Hummus & Pita Plate',
#      'Chile Lime Chicken Burrito',
#      'Pork Carnitas Burrito',
#      'Rajas Veggie Burrito',
#      'Tortilla Chips & Salsa',
#      'Makes Cents, Taco Salad',
#      'OTQ Nachos',
#      'Power Salad',
#      'Cherries & Crema Parfait',
#      'Barbacoa Beef Burrito',
#      'Italian Turkey Sand ',
#      'BLTA',
#      'Falafel Sand W/Roasted Tomato',
#      'Oven Roasted Potato Wedges']},
#    {'title': 'Made to Order Bowl - November 07th',
#     'items': ['Steamed Jasmine Rice',
#      'Sesame Cucumber Salad',
#      'Blanched Broccoli',
#      'Brown Rice',
#      'Avocado Vinaigrette Dressing',
#      'Sweet Soy Sauce',
#      'White Sesame Seeds',
#      'Marinated Yellowfin Tuna',
#      'Lime',
#      'Marinated Salmon',
#      'Fried Garlic',
#      'Red Cabbage ',
#      'OTQ Roasted Chicken Breast',
#      'Carrots ',
#      'Spicy Miso Aioli',
#      'Jalapeno Pepper ',
#      'Edamame ',
#      'Red Bell Pepper ',
#      'Daikon ',
#      'Green Onion ',
#      'Soy Marinated Love Strips',
#      'Romaine Lettuce ',
#      'USE MANGO CUBED   Mango Diced,']}]},
#  {'name': 'Rocket Burger *',
#   'times': ['9:30 AM - 7:00 PM'],
#   'building': 'Memorial Union',
#   'address': '',
#   'menus': []},
#  {'name': 'Happy Lemon *',
#   'times': ['10:00 AM - 7:00 PM'],
#   'building': 'Memorial Union',
#   'address': '',
#   'menus': []},
#  {'name': 'Panda Express *',
#   'times': ['10:00 AM - 8:00 PM'],
#   'building': 'Memorial Union',
#   'address': '',
#   'menus': []},
#  {'name': 'North Porch Cafe',
#   'times': ['10:30 AM - 2:30 PM'],
#   'building': 'Memorial Union',
#   'address': 'Inside\xa0Memorial Union, 2501 SW Jefferson Way, Corvallis, OR 97333',
#   'menus': [{'title': 'LUNCH - November 07th',
#     'items': ['Five Spice Pork Banh Mi',
#      'Asian Tofu Banh Mi',
#      'Thai BBQ Chicken Banh Mi',
#      'Steamed Chicken Potstickers',
#      'Soy Marinated Eggs',
#      'Noodle Salad W/Tofu',
#      'Cucumber & Edamame Salad',
#      'Noodle Salad W/Chicken',
#      'Vegetable Lo Mein']},
#    {'title': 'NP Made to Order BOWL - November 07th',
#     'items': ['Carrots ',
#      'Jalapeno Pepper ',
#      'Edamame ',
#      'Green Onion ',
#      'Cauliflower ',
#      'Mung Bean Sprout',
#      'Broccoli Florets ',
#      'Cilantro ',
#      'Korean Barbecue Sauce',
#      'Five Spice Pork',
#      'Brown Rice',
#      'Wonton Chip',
#      'Kimchi',
#      'Blanched Salted Peanuts',
#      'Yellow Coconut Curry Sauce',
#      'Steamed Jasmine Rice',
#      'Thai BBQ Chicken Thighs',
#      'Red Potato',
#      'Marinated & Roasted Tofu',
#      'Fried Onions ',
#      'Red Coconut Curry Sauce',
#      'Button Mushrooms ']}]},
#  {'name': 'Global Fare',
#   'times': ['7:00 AM - 10:30 AM', '11:00 AM - 2:00 PM', '5:00 PM - 8:00 PM'],
#   'building': 'Southside Station @ Arnold',
#   'address': 'Arnold Bistro, 681 SW 26th, Corvallis OR 97331',
#   'menus': [{'title': 'BREAKFAST - November 07th',
#     'items': ['Scrambled Eggs',
#      'French Toast',
#      "O'Brien Potatoes",
#      'Buttermilk Biscuit ',
#      'Hash Brown Triangles',
#      'Sausage Breakfast Gravy',
#      'Turkey Sausage Patty',
#      'Tofu Scramble with Vegetables',
#      'Vegan "Just Egg" Scramble',
#      'House Made Buttermilk Pancake',
#      'Pork Sausage Links',
#      'Bacon']},
#    {'title': 'LUNCH - November 07th',
#     'items': ['Sushi Rice',
#      'Fried Egg',
#      'Green Onions',
#      'Gochujang Chicken',
#      'Korean Spinach ',
#      'Korean Bean Sprouts',
#      'Bulgogi Mushrooms',
#      'Korean Barbecue Sauce',
#      'Fried Garlic',
#      'Shredded Carrots ',
#      'Kimchi Fried Rice',
#      'Sauteed Shiitake Mushrooms',
#      'Bulgogi Beef']},
#    {'title': 'DINNER - November 07th',
#     'items': ['Sushi Rice',
#      'Fried Egg',
#      'Green Onions',
#      'Gochujang Chicken',
#      'Korean Spinach ',
#      'Korean Bean Sprouts',
#      'Bulgogi Mushrooms',
#      'Korean Barbecue Sauce',
#      'Fried Garlic',
#      'Shredded Carrots ',
#      'Kimchi Fried Rice',
#      'Sauteed Shiitake Mushrooms',
#      'Bulgogi Beef']},
#    {'title': 'Grab & Go - November 07th',
#     'items': ['Country Breakfast Bowl',
#      'Breakfast Burrito with Veggies',
#      'Bacon and Sausage Breakfast Burrito',
#      'Plant Based Breakfast Burrito',
#      'Breakfast Bowl w/Veggies']}]},
#  {'name': 'Nori',
#   'times': ['11:00 AM - 2:30 PM', '5:00 PM - 8:00 PM'],
#   'building': 'Southside Station @ Arnold',
#   'address': 'Arnold Bistro, 681 SW 26th, Corvallis OR 97331',
#   'menus': [{'title': 'NORI GRILL - November 07th',
#     'items': ['Fried Tofu Teriyaki Bowl',
#      'Japanese Vegetable Curry',
#      'Spicy Korean Pork Bowl w/Kimchi',
#      'Chicken Teriyaki Bowl',
#      'Beef Teriyaki Bowl']},
#    {'title': 'Made to Order Bowl - November 07th',
#     'items': ['Soft Poached Egg',
#      'Teriyaki Marinated Chicken Thighs',
#      'Tonkotsu Broth',
#      'Ramen Noodles',
#      'Rice Noodles ',
#      'Green Onions',
#      'Hardcooked Eggs ',
#      'Mung Bean Sprout',
#      'Bamboo Shoot Strips',
#      'Honey Cured Bacon ',
#      'Shitake Mushroom, Dried',
#      'Fried Garlic',
#      'Yakinori Blue Nori',
#      'Tofu ',
#      'Shoyu Broth',
#      'Whole Kernal Corn ',
#      'Miso Broth',
#      'Udon Noodles']},
#    {'title': 'SIDES - November 07th',
#     'items': ['Togarashi Tots',
#      'Vegetable Spring Rolls w/Sweet Chili Sauce',
#      'Pok Pok Wing Sauce',
#      'Pok Pok Chicken Wings']},
#    {'title': 'Make Cents - November 07th',
#     'items': ['Make Cents Teriyaki Chicken and Noodles',
#      'Make Cents Crispy Tofu and Yakisoba Noodles',
#      'Make Cents, Teriyaki Beef and Yakisoba Noodles']},
#    {'title': 'NORI SUSHI - November 07th',
#     'items': ['Sushi, California Roll',
#      'Sushi, Cucumber Avocado Roll',
#      'Sushi, Vegetable Roll']}]},
#  {'name': 'Grill',
#   'times': ['11:00 AM - 7:30 PM'],
#   'building': 'Southside Station @ Arnold',
#   'address': '',
#   'menus': [{'title': 'Made to Order Burger - November 07th',
#     'items': ['Bohemian Black Bean Patty',
#      'Dill Pickle Chip',
#      'Sliced Swiss Cheese',
#      'Sliced Pepper Jack Cheese ',
#      'Sliced Cheddar Cheese',
#      'Sliced Pickled Jalapeno',
#      'Red Onion ',
#      'Lamb Patty',
#      'Vegan Cheddar Cheese ',
#      'Halal Grass Fed Beef Patties ',
#      'Fry Sauce',
#      'Chicken Breast ',
#      'Lettuce ',
#      'Spicy Fry Sauce',
#      'Roma Tomato ',
#      'Hamburger Bun, VGN, GF ',
#      'Wheat Hamburger Bun w/Oat Topping ',
#      'Potato Hamburger Bun ']},
#    {'title': 'ADD-ONS - November 07th',
#     'items': ['Caramelized Yellow Onions',
#      "Calabaloo's French Fries",
#      "Calabaloo's Chicken Strips",
#      "Calabaloo's Sauteed Mushrooms",
#      'Guacamole ',
#      'Pineapple Rings ',
#      'Bacon']},
#    {'title': 'Specials / Promos - November 07th',
#     'items': ["Calabaloo's Cowboy Burger"]},
#    {'title': 'Make Cents - November 07th',
#     'items': ['Make Cents, Chili Cheese Fries']}]},
#  {'name': 'Southside Station Deli',
#   'times': ['10:30 AM - 5:00 PM'],
#   'building': 'Southside Station @ Arnold',
#   'address': 'Arnold Bistro,     681 SW 26th,    Corvallis OR 97331',
#   'menus': [{'title': 'Made to Order Sandwich - November 07th',
#     'items': ['Tuna Salad',
#      'Egg Salad',
#      'Chipotle Mayonnaise',
#      'Chicken Breast in Strips, Halal',
#      'Vegan Chimichurri Mayo',
#      'Pepperoncini ',
#      'Dill Pickle Chip',
#      'Sliced Swiss Cheese',
#      'Sliced Pepper Jack Cheese ',
#      'Deli Turkey Breast ',
#      'Kronos Hummus',
#      'Sliced Cheddar Cheese',
#      'Sliced Provolone Cheese',
#      'Deli Ham ',
#      'Yellow Mustard',
#      'White Deli Bread Gluten Free ',
#      'Wheat Bread ',
#      'Mayonnaise',
#      'Basil Pesto Sauce',
#      'Red Bell Pepper ',
#      'Red Onion ',
#      'Tomato ',
#      'Vegan Cheddar Cheese ',
#      'Lettuce ',
#      'Guacamole ',
#      'Teardrop Naan',
#      'Roast Beef ',
#      'Honey Cured Bacon ',
#      'Eggless Mayonnaise Spread ',
#      'Whole Wheat Hoagie ',
#      'Curved Croissant, 3.7oz',
#      'Hoagie Roll 8" ',
#      'Cucumber ',
#      'Vegan American Cheese ']},
#    {'title': 'SOUP - November 07th',
#     'items': ['Tomato Soup - House Made',
#      'Clam Chowder',
#      'Tuscan Bean Soup w/Pancetta - House Made',
#      'House Potato Corn Soup',
#      'House Country Harvest Tomato & Vegetable Soup',
#      'House Vegetable Barley Soup',
#      'House Wild Rice Vegetable Soup',
#      'Italian Wedding w/Meatballs Soup',
#      'Tuscan Bean Soup - House Made',
#      'House Made Vegetable Beef and Barley Soup',
#      'Lentil & Ham Soup, House Made']},
#    {'title': 'PANINIS - November 07th',
#     'items': ['Cheesesteak Panini',
#      'Mushroom Panini',
#      'Italian Panini',
#      'Hummus & Feta Panini']},
#    {'title': 'Make Cents - November 07th',
#     'items': ['Make Cents, Cheese Pizza Bagel w/Side Salad']},
#    {'title': 'Grab & Go - November 07th',
#     'items': ['Strawberry Yogurt Parfait',
#      'Grab and Go Potato Salad',
#      'Grab and Go Island Mac Salad',
#      'Grab and Go Loaded Potato Salad',
#      'Grab and Go Ham & Swiss Sandwich',
#      'Grab and Go Turkey & Cheddar Sandwich',
#      'Grab and Go Blueberry Parfait',
#      'Grab and Go Fruit Cup 4oz',
#      'Grab and Go Fruit Cup 12oz',
#      'Grab and Go Broccoli Salad 12oz',
#      'Grab and Go Chickpea Salad Sandwich',
#      'Grab and Go Pesto Rotini Salad',
#      'Grab and Go Diced Bacon',
#      'Grab and Go Diced Chicken',
#      'Grab and Go Southwest Vegan Black Bean Wrap']},
#    {'title': 'ARNOLD SALAD BAR - November 07th',
#     'items': ['Roasted Beets',
#      'Roasted Broccoli',
#      "Calabaloo's Sauteed Mushrooms",
#      'Marinated Red Onion',
#      'Roasted Radishes',
#      'Crispy Fried Seasoned Tofu',
#      'Pepperoncini ',
#      'Balsamic Vinaigrette Dressing ',
#      'Feta Cheese Crumbles',
#      'Honey Mustard Dressing ',
#      'Spring Mix Lettuce ',
#      'Carrots ',
#      'Edamame ',
#      'Red Bell Pepper ',
#      'Shredded Cheddar Cheese',
#      'Homestyle Ranch Dressing ',
#      'Creamy Caesar Dressing ',
#      'Grape Tomato',
#      'Hardcooked Eggs ',
#      'Garbanzo Beans, Low Sodium',
#      'Cottage Cheese',
#      'Spinach ',
#      'Whole Kernal Corn ',
#      'Cucumber ',
#      'Whole Baby Corn',
#      'Mandarin Orange Segments ',
#      'Kalamata Olives ',
#      'Romaine Lettuce ',
#      'Black Beans ',
#      'Greggorio Italian Dressing ',
#      'Green Peas ',
#      'Shredded Parmesan',
#      'Sliced Pears in Juice',
#      'Grilled Roasted Artichoke']}]},
#  {'name': 'Southside Station Pizzeria',
#   'times': ['11:30 AM - 1:30 PM', '5:00 PM - 7:00 PM'],
#   'building': 'Southside Station @ Arnold',
#   'address': 'Arnold Bistro, 681 SW 26th, Corvallis OR 97331',
#   'menus': [{'title': 'LUNCH - November 07th',
#     'items': ['Pepperoni Pizza Summer',
#      'Southside Ham & Pineapple Pizza Summer',
#      'Chicken Bacon Artichoke Pizza Summer',
#      'Vegetarian Pizza Summer',
#      'Cheese Pizza Summer']},
#    {'title': 'DINNER - November 07th',
#     'items': ['Pepperoni Pizza Summer',
#      'Southside Ham & Pineapple Pizza Summer',
#      'Chicken Bacon Artichoke Pizza Summer',
#      'Vegetarian Pizza Summer',
#      'Cheese Pizza Summer']},
#    {'title': 'Specials / Promos - November 07th', 'items': ['Meatball Pizza']},
#    {'title': 'PIZZA STATION - November 07th',
#     'items': ['Cheese Pizza', 'Pepperoni Pizza', 'Vegetarian Pizza']}]},
#  {'name': 'The Dam',
#   'times': ['7:30 AM - 6:30 PM'],
#   'building': 'The Learning Innovation Center',
#   'address': 'Inside Learning Innovation Center, 165 SW Sackett Pl, Corvallis, OR 97331',
#   'menus': []},
#  {'name': 'Java II',
#   'times': ['7:30 AM - 10:00 PM'],
#   'building': 'Valley Library',
#   'address': 'Inside The Valley Library, 121 The Valley Library, Corvallis, OR 97331',
#   'menus': []},
#  {'name': "Bing's Cafe",
#   'times': ['7:30 AM - 8:00 PM'],
#   'building': 'Weatherford Hall',
#   'address': 'Weatherford Hall, 300 SW 26th St, Corvallis OR 97331',
#   'menus': []}]
